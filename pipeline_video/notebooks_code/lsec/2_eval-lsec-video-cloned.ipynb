# %% [markdown]
# ### Evaluation

# %% [markdown]
# ##### LSEC

# %%
import os
os.getcwd()
# %cd syncnet_python/
# Out:
# /home/ldap-users-2/lathifgalih-k/clone-video/syncnet_python

# %%
import warnings
import os

# Suppress warnings
warnings.filterwarnings('ignore')
os.environ['PYTHONWARNINGS'] = 'ignore'

# For LRS datasets, use the LRS evaluation script
# !python calculate_scores_LRS.py --data_root /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/muse-exp/MuseTalk/test_lsec --tmp_dir tmp_dir/
# Out:
# Avg Confidence: 4.129, Avg Minimum Dist: 10.272: 100%|█| 1/1 [00:01<00:00,  1.53
# Average Confidence: 4.129159927368164
# Average Minimum Distance: 10.271806716918945

# %% [markdown]
# #### LSE for All Data

# %%
import warnings
import os
import pandas as pd
import numpy as np
import subprocess
import glob
import shutil
from collections import defaultdict

# Suppress warnings
warnings.filterwarnings('ignore')
os.environ['PYTHONWARNINGS'] = 'ignore'

def extract_info_from_filename(filename):
    """Extract speaker ID and TTS method from filename"""
    basename = os.path.basename(filename)
    
    # Extract TTS method
    if "_CV_" in basename:
        tts_method = "CosyVoice"
    elif "_XT_" in basename:
        tts_method = "XTTSv2"
    elif "_YT_" in basename:
        tts_method = "YourTTS"
    else:
        tts_method = "Unknown"
    
    # Extract speaker ID (first part)
    speaker_id = basename.split('_')[0]  # A002, A006, S001, etc.
    
    return speaker_id, tts_method

def calculate_lse_batch(video_folder, dataset_name):
    """Calculate LSE scores for all videos in a folder using calculate_scores_LRS.py"""
    print(f"Calculating LSE scores for {dataset_name} videos in: {video_folder}")
    
    # Create temporary directory for this dataset
    tmp_dir = f"tmp_dir_{dataset_name}"
    
    try:
        # Run syncnet evaluation using calculate_scores_LRS.py
        cmd = [
            'python', 'calculate_scores_LRS.py', 
            '--data_root', video_folder,
            '--tmp_dir', tmp_dir
        ]
        
        # Suppress warnings
        env = os.environ.copy()
        env['PYTHONWARNINGS'] = 'ignore'
        
        print(f"Running command: {' '.join(cmd)}")
        result = subprocess.run(cmd, capture_output=True, text=True, env=env)
        
        print("STDOUT:", result.stdout)
        if result.stderr:
            print("STDERR:", result.stderr)
        
        # Parse results from stdout
        output_lines = result.stdout.split('\n')
        
        avg_confidence = None
        avg_min_distance = None
        
        for line in output_lines:
            if 'Average Confidence:' in line:
                try:
                    avg_confidence = float(line.split('Average Confidence:')[1].strip())
                except:
                    pass
            if 'Average Minimum Distance:' in line:
                try:
                    avg_min_distance = float(line.split('Average Minimum Distance:')[1].strip())
                except:
                    pass
        
        print(f"\n{dataset_name} Results:")
        print(f"  Average Confidence (LSE-C): {avg_confidence:.4f}" if avg_confidence else "  LSE-C: Not found")
        print(f"  Average Minimum Distance (LSE-D): {avg_min_distance:.4f}" if avg_min_distance else "  LSE-D: Not found")
        
        return avg_confidence, avg_min_distance
            
    except Exception as e:
        print(f"Error running syncnet: {e}")
        return None, None
    finally:
        # Clean up temporary directory
        if os.path.exists(tmp_dir):
            shutil.rmtree(tmp_dir)

# Define video folders to evaluate
video_folders = [
    "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/muse-exp/MuseTalk/results/test_raw/v15/RAW",
    "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/muse-exp/MuseTalk/results/test_vctk/v15/VCTK"
]

dataset_names = ["RAW", "VCTK"]

all_results = []
lse_d_scores = defaultdict(list)
lse_c_scores = defaultdict(list)
speaker_scores = defaultdict(lambda: defaultdict(list))

print("Starting LSE evaluation using calculate_scores_LRS.py...")
print("=" * 60)

for dataset_name, video_folder in zip(dataset_names, video_folders):
    if not os.path.exists(video_folder):
        print(f"Warning: Video folder not found: {video_folder}")
        continue
    
    print(f"\nProcessing {dataset_name} dataset...")
    print(f"Folder: {video_folder}")
    
    # Get all mp4 files
    video_files = glob.glob(os.path.join(video_folder, "*.mp4"))
    print(f"Found {len(video_files)} video files")
    
    if len(video_files) == 0:
        print("No video files found, skipping...")
        continue
    
    # Show first few files
    print("Sample files:")
    for i, vf in enumerate(video_files[:5]):
        print(f"  {i+1}. {os.path.basename(vf)}")
    
    # Calculate LSE scores for this dataset
    lse_c, lse_d = calculate_lse_batch(video_folder, dataset_name)
    
    if lse_c is not None and lse_d is not None:
        print(f"\n{dataset_name} Overall Scores:")
        print(f"  LSE-C (Confidence): {lse_c:.4f}")
        print(f"  LSE-D (Distance): {lse_d:.4f}")
        
        # Process each video file to get individual info
        for video_file in video_files:
            speaker_id, tts_method = extract_info_from_filename(video_file)
            
            # Store individual result (using overall scores for the dataset)
            result = {
                'dataset': dataset_name,
                'speaker_id': speaker_id,
                'tts_method': tts_method,
                'lse_d_score': lse_d,
                'lse_c_score': lse_c,
                'video_file': os.path.basename(video_file)
            }
            all_results.append(result)
            
            # Store for averaging by TTS method
            key = f"{dataset_name}_{tts_method}"
            lse_d_scores[key].append(lse_d)
            lse_c_scores[key].append(lse_c)
            
            # Store for averaging by speaker
            speaker_key = f"{dataset_name}_{speaker_id}"
            speaker_scores[speaker_key]['lse_d'].append(lse_d)
            speaker_scores[speaker_key]['lse_c'].append(lse_c)
            speaker_scores[speaker_key]['tts_methods'].append(tts_method)
    else:
        print(f"Failed to get LSE scores for {dataset_name}")

print("\n" + "=" * 60)
print("LSE EVALUATION COMPLETE")
print("=" * 60)

# Convert to DataFrame
df = pd.DataFrame(all_results)

# Display results
if len(df) > 0:
    print("\nIndividual Results:")
    print(df[['dataset', 'speaker_id', 'tts_method', 'lse_d_score', 'lse_c_score']].to_string(index=False))
    
    # Averages per dataset and TTS method
    print("\n" + "=" * 60)
    print("AVERAGES PER DATASET AND TTS METHOD")
    print("=" * 60)
    
    tts_summary_data = []
    for dataset in ['RAW', 'VCTK']:
        for tts_method in ['CosyVoice', 'XTTSv2', 'YourTTS']:
            key = f"{dataset}_{tts_method}"
            if key in lse_d_scores and len(lse_d_scores[key]) > 0:
                avg_lse_d = np.mean(lse_d_scores[key])
                std_lse_d = np.std(lse_d_scores[key])
                avg_lse_c = np.mean(lse_c_scores[key])
                std_lse_c = np.std(lse_c_scores[key])
                count = len(lse_d_scores[key])
                
                print(f"\n{dataset} - {tts_method} ({count} samples):")
                print(f"  LSE-D: {avg_lse_d:.4f} ± {std_lse_d:.4f}")
                print(f"  LSE-C: {avg_lse_c:.4f} ± {std_lse_c:.4f}")
                
                tts_summary_data.append({
                    'Dataset': dataset,
                    'TTS_Method': tts_method,
                    'Count': count,
                    'LSE_D_Mean': avg_lse_d,
                    'LSE_D_Std': std_lse_d,
                    'LSE_C_Mean': avg_lse_c,
                    'LSE_C_Std': std_lse_c
                })
    
    # Averages per speaker
    print("\n" + "=" * 60)
    print("AVERAGES PER SPEAKER")
    print("=" * 60)
    
    speaker_summary_data = []
    for speaker_key in sorted(speaker_scores.keys()):
        if len(speaker_scores[speaker_key]['lse_d']) > 0:
            avg_lse_d = np.mean(speaker_scores[speaker_key]['lse_d'])
            std_lse_d = np.std(speaker_scores[speaker_key]['lse_d'])
            avg_lse_c = np.mean(speaker_scores[speaker_key]['lse_c'])
            std_lse_c = np.std(speaker_scores[speaker_key]['lse_c'])
            count = len(speaker_scores[speaker_key]['lse_d'])
            
            tts_methods = list(set(speaker_scores[speaker_key]['tts_methods']))
            dataset_name = speaker_key.split('_')[0]
            speaker_id = '_'.join(speaker_key.split('_')[1:])
            
            print(f"\n{speaker_key} ({count} samples, TTS: {', '.join(tts_methods)}):")
            print(f"  LSE-D: {avg_lse_d:.4f} ± {std_lse_d:.4f}")
            print(f"  LSE-C: {avg_lse_c:.4f} ± {std_lse_c:.4f}")
            
            speaker_summary_data.append({
                'Dataset': dataset_name,
                'Speaker_ID': speaker_id,
                'Count': count,
                'LSE_D_Mean': avg_lse_d,
                'LSE_D_Std': std_lse_d,
                'LSE_C_Mean': avg_lse_c,
                'LSE_C_Std': std_lse_c,
                'TTS_Methods': ', '.join(tts_methods)
            })
    
    # Create and display summary tables
    print("\n" + "=" * 60)
    print("SUMMARY TABLES")
    print("=" * 60)
    
    # TTS Method Summary
    tts_summary_df = pd.DataFrame(tts_summary_data)
    print("\nSummary by Dataset and TTS Method:")
    print(tts_summary_df.round(4).to_string(index=False))
    
    # Speaker Summary
    speaker_summary_df = pd.DataFrame(speaker_summary_data)
    print("\nSummary by Speaker:")
    print(speaker_summary_df.round(4).to_string(index=False))
    
    # Overall statistics per dataset
    print("\n" + "=" * 60)
    print("OVERALL STATISTICS PER DATASET")
    print("=" * 60)
    
    for dataset in ['RAW', 'VCTK']:
        dataset_results = df[df['dataset'] == dataset]
        if len(dataset_results) > 0:
            avg_lse_d = dataset_results['lse_d_score'].mean()
            std_lse_d = dataset_results['lse_d_score'].std()
            avg_lse_c = dataset_results['lse_c_score'].mean()
            std_lse_c = dataset_results['lse_c_score'].std()
            
            print(f"\n{dataset} Dataset:")
            print(f"  Total samples: {len(dataset_results)}")
            print(f"  LSE-D: {avg_lse_d:.4f} ± {std_lse_d:.4f}")
            print(f"  LSE-C: {avg_lse_c:.4f} ± {std_lse_c:.4f}")
    
    # Save results to CSV
    output_path = "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_results_lse.csv"
    df.to_csv(output_path, index=False)
    print(f"\nDetailed results saved to: {output_path}")
    
    # Save TTS summary
    tts_summary_output_path = "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_summary_lse_tts.csv"
    tts_summary_df.to_csv(tts_summary_output_path, index=False)
    print(f"TTS summary saved to: {tts_summary_output_path}")
    
    # Save speaker summary
    speaker_summary_output_path = "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_summary_lse_speaker.csv"
    speaker_summary_df.to_csv(speaker_summary_output_path, index=False)
    print(f"Speaker summary saved to: {speaker_summary_output_path}")

else:
    print("No results found!")

print("\nLSE evaluation completed successfully!")
# Out:
# Starting LSE evaluation using calculate_scores_LRS.py...
# ============================================================
#
# Processing RAW dataset...
# Folder: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/muse-exp/MuseTalk/results/test_raw/v15/RAW
# Found 60 video files
# Sample files:
#   1. A015_02_DDK_PATAKA_color_25fps_6sec_CV_A015_PATAKA_cloned.mp4
#   2. S011_02_BBP_NORMAL_color_25fps_6sec_YT_S011_BBP_cloned.mp4
#   3. A016_02_BBP_NORMAL_color_25fps_6sec_YT_A016_BBP_cloned.mp4
#   4. A017_02_BBP_NORMAL_color_25fps_6sec_CV_A017_BBP_cloned.mp4
#   5. A010_02_BBP_NORMAL_color_25fps_6sec_XT_A010_BBP_cloned.mp4
# Calculating LSE scores for RAW videos in: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/muse-exp/MuseTalk/results/test_raw/v15/RAW
# Running command: python calculate_scores_LRS.py --data_root /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/muse-exp/MuseTalk/results/test_raw/v15/RAW --tmp_dir tmp_dir_RAW
# STDOUT: Average Confidence: 2.7150182565053305
# Average Minimum Distance: 11.33853661219279
#
# STDERR:
#   0%|          | 0/60 [00:00<?, ?it/s]
# Avg Confidence: 1.248, Avg Minimum Dist: 10.608:   0%|          | 0/60 [00:01<?, ?it/s]
# Avg Confidence: 1.248, Avg Minimum Dist: 10.608:   0%|          | 0/60 [00:01<?, ?it/s]
# Avg Confidence: 1.248, Avg Minimum Dist: 10.608:   2%|▏         | 1/60 [00:01<01:19,  1.35s/it]
# Avg Confidence: 2.868, Avg Minimum Dist: 10.079:   2%|▏         | 1/60 [00:02<01:19,  1.35s/it]
# Avg Confidence: 2.868, Avg Minimum Dist: 10.079:   2%|▏         | 1/60 [00:02<01:19,  1.35s/it]
# Avg Confidence: 2.868, Avg Minimum Dist: 10.079:   3%|▎         | 2/60 [00:02<01:17,  1.34s/it]
# Avg Confidence: 2.282, Avg Minimum Dist: 11.45:   3%|▎         | 2/60 [00:04<01:17,  1.34s/it]
# Avg Confidence: 2.282, Avg Minimum Dist: 11.45:   3%|▎         | 2/60 [00:04<01:17,  1.34s/it]
# Avg Confidence: 2.282, Avg Minimum Dist: 11.45:   5%|▌         | 3/60 [00:04<01:19,  1.40s/it]
# Avg Confidence: 1.912, Avg Minimum Dist: 11.964:   5%|▌         | 3/60 [00:06<01:19,  1.40s/it]
# Avg Confidence: 1.912, Avg Minimum Dist: 11.964:   5%|▌         | 3/60 [00:06<01:19,  1.40s/it]
# Avg Confidence: 1.912, Avg Minimum Dist: 11.964:   7%|▋         | 4/60 [00:06<01:30,  1.62s/it]
# Avg Confidence: 1.646, Avg Minimum Dist: 11.823:   7%|▋         | 4/60 [00:08<01:30,  1.62s/it]
# Avg Confidence: 1.646, Avg Minimum Dist: 11.823:   7%|▋         | 4/60 [00:08<01:30,  1.62s/it]
# Avg Confidence: 1.646, Avg Minimum Dist: 11.823:   8%|▊         | 5/60 [00:08<01:43,  1.89s/it]
# Avg Confidence: 2.342, Avg Minimum Dist: 11.419:   8%|▊         | 5/60 [00:10<01:43,  1.89s/it]
# Avg Confidence: 2.342, Avg Minimum Dist: 11.419:   8%|▊         | 5/60 [00:10<01:43,  1.89s/it]
# Avg Confidence: 2.342, Avg Minimum Dist: 11.419:  10%|█         | 6/60 [00:10<01:37,  1.81s/it]
# Avg Confidence: 2.292, Avg Minimum Dist: 11.797:  10%|█         | 6/60 [00:11<01:37,  1.81s/it]
# Avg Confidence: 2.292, Avg Minimum Dist: 11.797:  10%|█         | 6/60 [00:11<01:37,  1.81s/it]
# Avg Confidence: 2.292, Avg Minimum Dist: 11.797:  12%|█▏        | 7/60 [00:11<01:34,  1.79s/it]
# Avg Confidence: 2.215, Avg Minimum Dist: 11.941:  12%|█▏        | 7/60 [00:13<01:34,  1.79s/it]
# Avg Confidence: 2.215, Avg Minimum Dist: 11.941:  12%|█▏        | 7/60 [00:13<01:34,  1.79s/it]
# Avg Confidence: 2.215, Avg Minimum Dist: 11.941:  13%|█▎        | 8/60 [00:13<01:28,  1.71s/it]
# Avg Confidence: 2.563, Avg Minimum Dist: 11.626:  13%|█▎        | 8/60 [00:15<01:28,  1.71s/it]
# Avg Confidence: 2.563, Avg Minimum Dist: 11.626:  13%|█▎        | 8/60 [00:15<01:28,  1.71s/it]
# Avg Confidence: 2.563, Avg Minimum Dist: 11.626:  15%|█▌        | 9/60 [00:15<01:26,  1.69s/it]
# Avg Confidence: 2.401, Avg Minimum Dist: 11.749:  15%|█▌        | 9/60 [00:16<01:26,  1.69s/it]
# Avg Confidence: 2.401, Avg Minimum Dist: 11.749:  15%|█▌        | 9/60 [00:16<01:26,  1.69s/it]
# Avg Confidence: 2.401, Avg Minimum Dist: 11.749:  17%|█▋        | 10/60 [00:16<01:25,  1.71s/it]
# Avg Confidence: 2.512, Avg Minimum Dist: 11.72:  17%|█▋        | 10/60 [00:18<01:25,  1.71s/it]
# Avg Confidence: 2.512, Avg Minimum Dist: 11.72:  17%|█▋        | 10/60 [00:18<01:25,  1.71s/it]
# Avg Confidence: 2.512, Avg Minimum Dist: 11.72:  18%|█▊        | 11/60 [00:18<01:17,  1.59s/it]
# Avg Confidence: 2.42, Avg Minimum Dist: 11.821:  18%|█▊        | 11/60 [00:21<01:17,  1.59s/it]
# Avg Confidence: 2.42, Avg Minimum Dist: 11.821:  18%|█▊        | 11/60 [00:21<01:17,  1.59s/it]
# Avg Confidence: 2.42, Avg Minimum Dist: 11.821:  20%|██        | 12/60 [00:21<01:41,  2.11s/it]
# Avg Confidence: 2.677, Avg Minimum Dist: 11.573:  20%|██        | 12/60 [00:23<01:41,  2.11s/it]
# Avg Confidence: 2.677, Avg Minimum Dist: 11.573:  20%|██        | 12/60 [00:23<01:41,  2.11s/it]
# Avg Confidence: 2.677, Avg Minimum Dist: 11.573:  22%|██▏       | 13/60 [00:23<01:34,  2.01s/it]
# Avg Confidence: 2.527, Avg Minimum Dist: 11.708:  22%|██▏       | 13/60 [00:24<01:34,  2.01s/it]
# Avg Confidence: 2.527, Avg Minimum Dist: 11.708:  22%|██▏       | 13/60 [00:24<01:34,  2.01s/it]
# Avg Confidence: 2.527, Avg Minimum Dist: 11.708:  23%|██▎       | 14/60 [00:24<01:22,  1.79s/it]
# Avg Confidence: 2.654, Avg Minimum Dist: 11.642:  23%|██▎       | 14/60 [00:26<01:22,  1.79s/it]
# Avg Confidence: 2.654, Avg Minimum Dist: 11.642:  23%|██▎       | 14/60 [00:26<01:22,  1.79s/it]
# Avg Confidence: 2.654, Avg Minimum Dist: 11.642:  25%|██▌       | 15/60 [00:26<01:21,  1.82s/it]
# Avg Confidence: 2.498, Avg Minimum Dist: 11.727:  25%|██▌       | 15/60 [00:28<01:21,  1.82s/it]
# Avg Confidence: 2.498, Avg Minimum Dist: 11.727:  25%|██▌       | 15/60 [00:28<01:21,  1.82s/it]
# Avg Confidence: 2.498, Avg Minimum Dist: 11.727:  27%|██▋       | 16/60 [00:28<01:24,  1.93s/it]
# Avg Confidence: 2.529, Avg Minimum Dist: 11.669:  27%|██▋       | 16/60 [00:30<01:24,  1.93s/it]
# Avg Confidence: 2.529, Avg Minimum Dist: 11.669:  27%|██▋       | 16/60 [00:30<01:24,  1.93s/it]
# Avg Confidence: 2.529, Avg Minimum Dist: 11.669:  28%|██▊       | 17/60 [00:30<01:23,  1.94s/it]
# Avg Confidence: 2.485, Avg Minimum Dist: 11.746:  28%|██▊       | 17/60 [00:32<01:23,  1.94s/it]
# Avg Confidence: 2.485, Avg Minimum Dist: 11.746:  28%|██▊       | 17/60 [00:32<01:23,  1.94s/it]
# Avg Confidence: 2.485, Avg Minimum Dist: 11.746:  30%|███       | 18/60 [00:32<01:18,  1.87s/it]
# Avg Confidence: 2.598, Avg Minimum Dist: 11.646:  30%|███       | 18/60 [00:34<01:18,  1.87s/it]
# Avg Confidence: 2.598, Avg Minimum Dist: 11.646:  30%|███       | 18/60 [00:34<01:18,  1.87s/it]
# Avg Confidence: 2.598, Avg Minimum Dist: 11.646:  32%|███▏      | 19/60 [00:34<01:18,  1.91s/it]
# Avg Confidence: 2.62, Avg Minimum Dist: 11.74:  32%|███▏      | 19/60 [00:36<01:18,  1.91s/it]
# Avg Confidence: 2.62, Avg Minimum Dist: 11.74:  32%|███▏      | 19/60 [00:36<01:18,  1.91s/it]
# Avg Confidence: 2.62, Avg Minimum Dist: 11.74:  33%|███▎      | 20/60 [00:36<01:20,  2.02s/it]
# Avg Confidence: 2.559, Avg Minimum Dist: 11.774:  33%|███▎      | 20/60 [00:37<01:20,  2.02s/it]
# Avg Confidence: 2.559, Avg Minimum Dist: 11.774:  33%|███▎      | 20/60 [00:37<01:20,  2.02s/it]
# Avg Confidence: 2.559, Avg Minimum Dist: 11.774:  35%|███▌      | 21/60 [00:37<01:11,  1.83s/it]
# Avg Confidence: 2.462, Avg Minimum Dist: 11.548:  35%|███▌      | 21/60 [00:39<01:11,  1.83s/it]
# Avg Confidence: 2.462, Avg Minimum Dist: 11.548:  35%|███▌      | 21/60 [00:39<01:11,  1.83s/it]
# Avg Confidence: 2.462, Avg Minimum Dist: 11.548:  37%|███▋      | 22/60 [00:39<01:09,  1.82s/it]
# Avg Confidence: 2.563, Avg Minimum Dist: 11.465:  37%|███▋      | 22/60 [00:41<01:09,  1.82s/it]
# Avg Confidence: 2.563, Avg Minimum Dist: 11.465:  37%|███▋      | 22/60 [00:41<01:09,  1.82s/it]
# Avg Confidence: 2.563, Avg Minimum Dist: 11.465:  38%|███▊      | 23/60 [00:41<01:09,  1.87s/it]
# Avg Confidence: 2.657, Avg Minimum Dist: 11.425:  38%|███▊      | 23/60 [00:44<01:09,  1.87s/it]
# Avg Confidence: 2.657, Avg Minimum Dist: 11.425:  38%|███▊      | 23/60 [00:44<01:09,  1.87s/it]
# Avg Confidence: 2.657, Avg Minimum Dist: 11.425:  40%|████      | 24/60 [00:44<01:17,  2.15s/it]
# Avg Confidence: 2.571, Avg Minimum Dist: 11.469:  40%|████      | 24/60 [00:46<01:17,  2.15s/it]
# Avg Confidence: 2.571, Avg Minimum Dist: 11.469:  40%|████      | 24/60 [00:46<01:17,  2.15s/it]
# Avg Confidence: 2.571, Avg Minimum Dist: 11.469:  42%|████▏     | 25/60 [00:46<01:13,  2.10s/it]
# Avg Confidence: 2.706, Avg Minimum Dist: 11.374:  42%|████▏     | 25/60 [00:48<01:13,  2.10s/it]
# Avg Confidence: 2.706, Avg Minimum Dist: 11.374:  42%|████▏     | 25/60 [00:48<01:13,  2.10s/it]
# Avg Confidence: 2.706, Avg Minimum Dist: 11.374:  43%|████▎     | 26/60 [00:48<01:07,  1.99s/it]
# Avg Confidence: 2.703, Avg Minimum Dist: 11.398:  43%|████▎     | 26/60 [00:50<01:07,  1.99s/it]
# Avg Confidence: 2.703, Avg Minimum Dist: 11.398:  43%|████▎     | 26/60 [00:50<01:07,  1.99s/it]
# Avg Confidence: 2.703, Avg Minimum Dist: 11.398:  45%|████▌     | 27/60 [00:50<01:07,  2.03s/it]
# Avg Confidence: 2.647, Avg Minimum Dist: 11.462:  45%|████▌     | 27/60 [00:51<01:07,  2.03s/it]
# Avg Confidence: 2.647, Avg Minimum Dist: 11.462:  45%|████▌     | 27/60 [00:51<01:07,  2.03s/it]
# Avg Confidence: 2.647, Avg Minimum Dist: 11.462:  47%|████▋     | 28/60 [00:51<00:58,  1.84s/it]
# Avg Confidence: 2.714, Avg Minimum Dist: 11.415:  47%|████▋     | 28/60 [00:53<00:58,  1.84s/it]
# Avg Confidence: 2.714, Avg Minimum Dist: 11.415:  47%|████▋     | 28/60 [00:53<00:58,  1.84s/it]
# Avg Confidence: 2.714, Avg Minimum Dist: 11.415:  48%|████▊     | 29/60 [00:53<00:56,  1.83s/it]
# Avg Confidence: 2.672, Avg Minimum Dist: 11.487:  48%|████▊     | 29/60 [00:55<00:56,  1.83s/it]
# Avg Confidence: 2.672, Avg Minimum Dist: 11.487:  48%|████▊     | 29/60 [00:55<00:56,  1.83s/it]
# Avg Confidence: 2.672, Avg Minimum Dist: 11.487:  50%|█████     | 30/60 [00:55<00:56,  1.89s/it]
# Avg Confidence: 2.822, Avg Minimum Dist: 11.372:  50%|█████     | 30/60 [00:57<00:56,  1.89s/it]
# Avg Confidence: 2.822, Avg Minimum Dist: 11.372:  50%|█████     | 30/60 [00:57<00:56,  1.89s/it]
# Avg Confidence: 2.822, Avg Minimum Dist: 11.372:  52%|█████▏    | 31/60 [00:57<00:59,  2.04s/it]
# Avg Confidence: 2.767, Avg Minimum Dist: 11.398:  52%|█████▏    | 31/60 [01:00<00:59,  2.04s/it]
# Avg Confidence: 2.767, Avg Minimum Dist: 11.398:  52%|█████▏    | 31/60 [01:00<00:59,  2.04s/it]
# Avg Confidence: 2.767, Avg Minimum Dist: 11.398:  53%|█████▎    | 32/60 [01:00<00:57,  2.06s/it]
# Avg Confidence: 2.771, Avg Minimum Dist: 11.37:  53%|█████▎    | 32/60 [01:02<00:57,  2.06s/it]
# Avg Confidence: 2.771, Avg Minimum Dist: 11.37:  53%|█████▎    | 32/60 [01:02<00:57,  2.06s/it]
# Avg Confidence: 2.771, Avg Minimum Dist: 11.37:  55%|█████▌    | 33/60 [01:02<00:56,  2.10s/it]
# Avg Confidence: 2.708, Avg Minimum Dist: 11.429:  55%|█████▌    | 33/60 [01:05<00:56,  2.10s/it]
# Avg Confidence: 2.708, Avg Minimum Dist: 11.429:  55%|█████▌    | 33/60 [01:05<00:56,  2.10s/it]
# Avg Confidence: 2.708, Avg Minimum Dist: 11.429:  57%|█████▋    | 34/60 [01:05<01:00,  2.32s/it]
# Avg Confidence: 2.718, Avg Minimum Dist: 11.426:  57%|█████▋    | 34/60 [01:07<01:00,  2.32s/it]
# Avg Confidence: 2.718, Avg Minimum Dist: 11.426:  57%|█████▋    | 34/60 [01:07<01:00,  2.32s/it]
# Avg Confidence: 2.718, Avg Minimum Dist: 11.426:  58%|█████▊    | 35/60 [01:07<00:59,  2.37s/it]
# Avg Confidence: 2.743, Avg Minimum Dist: 11.415:  58%|█████▊    | 35/60 [01:08<00:59,  2.37s/it]
# Avg Confidence: 2.743, Avg Minimum Dist: 11.415:  58%|█████▊    | 35/60 [01:08<00:59,  2.37s/it]
# Avg Confidence: 2.743, Avg Minimum Dist: 11.415:  60%|██████    | 36/60 [01:08<00:48,  2.04s/it]
# Avg Confidence: 2.678, Avg Minimum Dist: 11.46:  60%|██████    | 36/60 [01:10<00:48,  2.04s/it]
# Avg Confidence: 2.678, Avg Minimum Dist: 11.46:  60%|██████    | 36/60 [01:10<00:48,  2.04s/it]
# Avg Confidence: 2.678, Avg Minimum Dist: 11.46:  62%|██████▏   | 37/60 [01:10<00:43,  1.89s/it]
# Avg Confidence: 2.763, Avg Minimum Dist: 11.389:  62%|██████▏   | 37/60 [01:11<00:43,  1.89s/it]
# Avg Confidence: 2.763, Avg Minimum Dist: 11.389:  62%|██████▏   | 37/60 [01:11<00:43,  1.89s/it]
# Avg Confidence: 2.763, Avg Minimum Dist: 11.389:  63%|██████▎   | 38/60 [01:11<00:39,  1.79s/it]
# Avg Confidence: 2.749, Avg Minimum Dist: 11.445:  63%|██████▎   | 38/60 [01:14<00:39,  1.79s/it]
# Avg Confidence: 2.749, Avg Minimum Dist: 11.445:  63%|██████▎   | 38/60 [01:14<00:39,  1.79s/it]
# Avg Confidence: 2.749, Avg Minimum Dist: 11.445:  65%|██████▌   | 39/60 [01:14<00:39,  1.87s/it]
# Avg Confidence: 2.788, Avg Minimum Dist: 11.406:  65%|██████▌   | 39/60 [01:16<00:39,  1.87s/it]
# Avg Confidence: 2.788, Avg Minimum Dist: 11.406:  65%|██████▌   | 39/60 [01:16<00:39,  1.87s/it]
# Avg Confidence: 2.788, Avg Minimum Dist: 11.406:  67%|██████▋   | 40/60 [01:16<00:38,  1.93s/it]
# Avg Confidence: 2.742, Avg Minimum Dist: 11.426:  67%|██████▋   | 40/60 [01:17<00:38,  1.93s/it]
# Avg Confidence: 2.742, Avg Minimum Dist: 11.426:  67%|██████▋   | 40/60 [01:17<00:38,  1.93s/it]
# Avg Confidence: 2.742, Avg Minimum Dist: 11.426:  68%|██████▊   | 41/60 [01:17<00:34,  1.82s/it]
# Avg Confidence: 2.771, Avg Minimum Dist: 11.434:  68%|██████▊   | 41/60 [01:19<00:34,  1.82s/it]
# Avg Confidence: 2.771, Avg Minimum Dist: 11.434:  68%|██████▊   | 41/60 [01:19<00:34,  1.82s/it]
# Avg Confidence: 2.771, Avg Minimum Dist: 11.434:  70%|███████   | 42/60 [01:19<00:33,  1.85s/it]
# Avg Confidence: 2.785, Avg Minimum Dist: 11.41:  70%|███████   | 42/60 [01:21<00:33,  1.85s/it]
# Avg Confidence: 2.785, Avg Minimum Dist: 11.41:  70%|███████   | 42/60 [01:21<00:33,  1.85s/it]
# Avg Confidence: 2.785, Avg Minimum Dist: 11.41:  72%|███████▏  | 43/60 [01:21<00:33,  1.99s/it]
# Avg Confidence: 2.748, Avg Minimum Dist: 11.476:  72%|███████▏  | 43/60 [01:25<00:33,  1.99s/it]
# Avg Confidence: 2.748, Avg Minimum Dist: 11.476:  72%|███████▏  | 43/60 [01:25<00:33,  1.99s/it]
# Avg Confidence: 2.748, Avg Minimum Dist: 11.476:  73%|███████▎  | 44/60 [01:25<00:40,  2.52s/it]
# Avg Confidence: 2.78, Avg Minimum Dist: 11.434:  73%|███████▎  | 44/60 [01:27<00:40,  2.52s/it]
# Avg Confidence: 2.78, Avg Minimum Dist: 11.434:  73%|███████▎  | 44/60 [01:27<00:40,  2.52s/it]
# Avg Confidence: 2.78, Avg Minimum Dist: 11.434:  75%|███████▌  | 45/60 [01:27<00:33,  2.25s/it]
# Avg Confidence: 2.752, Avg Minimum Dist: 11.481:  75%|███████▌  | 45/60 [01:29<00:33,  2.25s/it]
# Avg Confidence: 2.752, Avg Minimum Dist: 11.481:  75%|███████▌  | 45/60 [01:29<00:33,  2.25s/it]
# Avg Confidence: 2.752, Avg Minimum Dist: 11.481:  77%|███████▋  | 46/60 [01:29<00:30,  2.17s/it]
# Avg Confidence: 2.781, Avg Minimum Dist: 11.455:  77%|███████▋  | 46/60 [01:30<00:30,  2.17s/it]
# Avg Confidence: 2.781, Avg Minimum Dist: 11.455:  77%|███████▋  | 46/60 [01:30<00:30,  2.17s/it]
# Avg Confidence: 2.781, Avg Minimum Dist: 11.455:  78%|███████▊  | 47/60 [01:30<00:25,  1.95s/it]
# Avg Confidence: 2.79, Avg Minimum Dist: 11.434:  78%|███████▊  | 47/60 [01:32<00:25,  1.95s/it]
# Avg Confidence: 2.79, Avg Minimum Dist: 11.434:  78%|███████▊  | 47/60 [01:32<00:25,  1.95s/it]
# Avg Confidence: 2.79, Avg Minimum Dist: 11.434:  80%|████████  | 48/60 [01:32<00:24,  2.06s/it]
# Avg Confidence: 2.763, Avg Minimum Dist: 11.493:  80%|████████  | 48/60 [01:35<00:24,  2.06s/it]
# Avg Confidence: 2.763, Avg Minimum Dist: 11.493:  80%|████████  | 48/60 [01:35<00:24,  2.06s/it]
# Avg Confidence: 2.763, Avg Minimum Dist: 11.493:  82%|████████▏ | 49/60 [01:35<00:22,  2.07s/it]
# Avg Confidence: 2.79, Avg Minimum Dist: 11.471:  82%|████████▏ | 49/60 [01:38<00:22,  2.07s/it]
# Avg Confidence: 2.79, Avg Minimum Dist: 11.471:  82%|████████▏ | 49/60 [01:38<00:22,  2.07s/it]
# Avg Confidence: 2.79, Avg Minimum Dist: 11.471:  83%|████████▎ | 50/60 [01:38<00:25,  2.58s/it]
# Avg Confidence: 2.742, Avg Minimum Dist: 11.472:  83%|████████▎ | 50/60 [01:42<00:25,  2.58s/it]
# Avg Confidence: 2.742, Avg Minimum Dist: 11.472:  83%|████████▎ | 50/60 [01:42<00:25,  2.58s/it]
# Avg Confidence: 2.742, Avg Minimum Dist: 11.472:  85%|████████▌ | 51/60 [01:42<00:25,  2.85s/it]
# Avg Confidence: 2.704, Avg Minimum Dist: 11.466:  85%|████████▌ | 51/60 [01:45<00:25,  2.85s/it]
# Avg Confidence: 2.704, Avg Minimum Dist: 11.466:  85%|████████▌ | 51/60 [01:45<00:25,  2.85s/it]
# Avg Confidence: 2.704, Avg Minimum Dist: 11.466:  87%|████████▋ | 52/60 [01:45<00:23,  2.94s/it]
# Avg Confidence: 2.667, Avg Minimum Dist: 11.498:  87%|████████▋ | 52/60 [01:49<00:23,  2.94s/it]
# Avg Confidence: 2.667, Avg Minimum Dist: 11.498:  87%|████████▋ | 52/60 [01:49<00:23,  2.94s/it]
# Avg Confidence: 2.667, Avg Minimum Dist: 11.498:  88%|████████▊ | 53/60 [01:49<00:22,  3.16s/it]
# Avg Confidence: 2.703, Avg Minimum Dist: 11.456:  88%|████████▊ | 53/60 [01:51<00:22,  3.16s/it]
# Avg Confidence: 2.703, Avg Minimum Dist: 11.456:  88%|████████▊ | 53/60 [01:51<00:22,  3.16s/it]
# Avg Confidence: 2.703, Avg Minimum Dist: 11.456:  90%|█████████ | 54/60 [01:51<00:16,  2.83s/it]
# Avg Confidence: 2.756, Avg Minimum Dist: 11.405:  90%|█████████ | 54/60 [01:52<00:16,  2.83s/it]
# Avg Confidence: 2.756, Avg Minimum Dist: 11.405:  90%|█████████ | 54/60 [01:52<00:16,  2.83s/it]
# Avg Confidence: 2.756, Avg Minimum Dist: 11.405:  92%|█████████▏| 55/60 [01:52<00:11,  2.40s/it]
# Avg Confidence: 2.717, Avg Minimum Dist: 11.373:  92%|█████████▏| 55/60 [01:53<00:11,  2.40s/it]
# Avg Confidence: 2.717, Avg Minimum Dist: 11.373:  92%|█████████▏| 55/60 [01:53<00:11,  2.40s/it]
# Avg Confidence: 2.717, Avg Minimum Dist: 11.373:  93%|█████████▎| 56/60 [01:53<00:08,  2.05s/it]
# Avg Confidence: 2.763, Avg Minimum Dist: 11.336:  93%|█████████▎| 56/60 [01:56<00:08,  2.05s/it]
# Avg Confidence: 2.763, Avg Minimum Dist: 11.336:  93%|█████████▎| 56/60 [01:56<00:08,  2.05s/it]
# Avg Confidence: 2.763, Avg Minimum Dist: 11.336:  95%|█████████▌| 57/60 [01:56<00:06,  2.12s/it]
# Avg Confidence: 2.724, Avg Minimum Dist: 11.343:  95%|█████████▌| 57/60 [01:58<00:06,  2.12s/it]
# Avg Confidence: 2.724, Avg Minimum Dist: 11.343:  95%|█████████▌| 57/60 [01:58<00:06,  2.12s/it]
# Avg Confidence: 2.724, Avg Minimum Dist: 11.343:  97%|█████████▋| 58/60 [01:58<00:04,  2.26s/it]
# Avg Confidence: 2.729, Avg Minimum Dist: 11.321:  97%|█████████▋| 58/60 [02:00<00:04,  2.26s/it]
# Avg Confidence: 2.729, Avg Minimum Dist: 11.321:  97%|█████████▋| 58/60 [02:00<00:04,  2.26s/it]
# Avg Confidence: 2.729, Avg Minimum Dist: 11.321:  98%|█████████▊| 59/60 [02:00<00:02,  2.17s/it]
# Avg Confidence: 2.715, Avg Minimum Dist: 11.339:  98%|█████████▊| 59/60 [02:02<00:02,  2.17s/it]
# Avg Confidence: 2.715, Avg Minimum Dist: 11.339:  98%|█████████▊| 59/60 [02:02<00:02,  2.17s/it]
# Avg Confidence: 2.715, Avg Minimum Dist: 11.339: 100%|██████████| 60/60 [02:02<00:00,  2.02s/it]
# Avg Confidence: 2.715, Avg Minimum Dist: 11.339: 100%|██████████| 60/60 [02:02<00:00,  2.04s/it]
#
#
# RAW Results:
#   Average Confidence (LSE-C): 2.7150
#   Average Minimum Distance (LSE-D): 11.3385
#
# RAW Overall Scores:
#   LSE-C (Confidence): 2.7150
#   LSE-D (Distance): 11.3385
#
# Processing VCTK dataset...
# Folder: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/muse-exp/MuseTalk/results/test_vctk/v15/VCTK
# Found 60 video files
# Sample files:
#   1. S013_02_BBP_NORMAL_color_25fps_6sec_CV_S013_VCTK_cloned.mp4
#   2. S012_02_BBP_NORMAL_color_25fps_6sec_YT_S012_VCTK_cloned.mp4
#   3. A010_02_BBP_NORMAL_color_25fps_6sec_CV_A010_VCTK_cloned.mp4
#   4. A011_02_BBP_NORMAL_color_25fps_6sec_YT_A011_VCTK_cloned.mp4
#   5. A002_02_BBP_NORMAL_color_25fps_6sec_CV_A002_VCTK_cloned.mp4
# Calculating LSE scores for VCTK videos in: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/muse-exp/MuseTalk/results/test_vctk/v15/VCTK
# Running command: python calculate_scores_LRS.py --data_root /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/muse-exp/MuseTalk/results/test_vctk/v15/VCTK --tmp_dir tmp_dir_VCTK
# STDOUT: Average Confidence: 2.2330480257670087
# Average Minimum Distance: 10.511787621180217
#
# STDERR:
#   0%|          | 0/60 [00:00<?, ?it/s]
# Avg Confidence: 0.669, Avg Minimum Dist: 12.93:   0%|          | 0/60 [00:01<?, ?it/s]
# Avg Confidence: 0.669, Avg Minimum Dist: 12.93:   0%|          | 0/60 [00:01<?, ?it/s]
# Avg Confidence: 0.669, Avg Minimum Dist: 12.93:   2%|▏         | 1/60 [00:01<01:49,  1.86s/it]
# Avg Confidence: 1.218, Avg Minimum Dist: 12.007:   2%|▏         | 1/60 [00:03<01:49,  1.86s/it]
# Avg Confidence: 1.218, Avg Minimum Dist: 12.007:   2%|▏         | 1/60 [00:03<01:49,  1.86s/it]
# Avg Confidence: 1.218, Avg Minimum Dist: 12.007:   3%|▎         | 2/60 [00:03<01:34,  1.63s/it]
# Avg Confidence: 0.881, Avg Minimum Dist: 12.107:   3%|▎         | 2/60 [00:04<01:34,  1.63s/it]
# Avg Confidence: 0.881, Avg Minimum Dist: 12.107:   3%|▎         | 2/60 [00:04<01:34,  1.63s/it]
# Avg Confidence: 0.881, Avg Minimum Dist: 12.107:   5%|▌         | 3/60 [00:04<01:30,  1.58s/it]
# Avg Confidence: 1.127, Avg Minimum Dist: 11.883:   5%|▌         | 3/60 [00:06<01:30,  1.58s/it]
# Avg Confidence: 1.127, Avg Minimum Dist: 11.883:   5%|▌         | 3/60 [00:06<01:30,  1.58s/it]
# Avg Confidence: 1.127, Avg Minimum Dist: 11.883:   7%|▋         | 4/60 [00:06<01:27,  1.57s/it]
# Avg Confidence: 1.387, Avg Minimum Dist: 11.61:   7%|▋         | 4/60 [00:07<01:27,  1.57s/it]
# Avg Confidence: 1.387, Avg Minimum Dist: 11.61:   7%|▋         | 4/60 [00:07<01:27,  1.57s/it]
# Avg Confidence: 1.387, Avg Minimum Dist: 11.61:   8%|▊         | 5/60 [00:07<01:21,  1.48s/it]
# Avg Confidence: 1.792, Avg Minimum Dist: 11.337:   8%|▊         | 5/60 [00:09<01:21,  1.48s/it]
# Avg Confidence: 1.792, Avg Minimum Dist: 11.337:   8%|▊         | 5/60 [00:09<01:21,  1.48s/it]
# Avg Confidence: 1.792, Avg Minimum Dist: 11.337:  10%|█         | 6/60 [00:09<01:34,  1.75s/it]
# Avg Confidence: 1.63, Avg Minimum Dist: 11.439:  10%|█         | 6/60 [00:11<01:34,  1.75s/it]
# Avg Confidence: 1.63, Avg Minimum Dist: 11.439:  10%|█         | 6/60 [00:11<01:34,  1.75s/it]
# Avg Confidence: 1.63, Avg Minimum Dist: 11.439:  12%|█▏        | 7/60 [00:11<01:26,  1.63s/it]
# Avg Confidence: 1.918, Avg Minimum Dist: 11.245:  12%|█▏        | 7/60 [00:12<01:26,  1.63s/it]
# Avg Confidence: 1.918, Avg Minimum Dist: 11.245:  12%|█▏        | 7/60 [00:12<01:26,  1.63s/it]
# Avg Confidence: 1.918, Avg Minimum Dist: 11.245:  13%|█▎        | 8/60 [00:12<01:22,  1.58s/it]
# Avg Confidence: 2.03, Avg Minimum Dist: 11.132:  13%|█▎        | 8/60 [00:14<01:22,  1.58s/it]
# Avg Confidence: 2.03, Avg Minimum Dist: 11.132:  13%|█▎        | 8/60 [00:14<01:22,  1.58s/it]
# Avg Confidence: 2.03, Avg Minimum Dist: 11.132:  15%|█▌        | 9/60 [00:14<01:26,  1.70s/it]
# Avg Confidence: 1.917, Avg Minimum Dist: 11.118:  15%|█▌        | 9/60 [00:16<01:26,  1.70s/it]
# Avg Confidence: 1.917, Avg Minimum Dist: 11.118:  15%|█▌        | 9/60 [00:16<01:26,  1.70s/it]
# Avg Confidence: 1.917, Avg Minimum Dist: 11.118:  17%|█▋        | 10/60 [00:16<01:19,  1.59s/it]
# Avg Confidence: 1.843, Avg Minimum Dist: 11.135:  17%|█▋        | 10/60 [00:17<01:19,  1.59s/it]
# Avg Confidence: 1.843, Avg Minimum Dist: 11.135:  17%|█▋        | 10/60 [00:17<01:19,  1.59s/it]
# Avg Confidence: 1.843, Avg Minimum Dist: 11.135:  18%|█▊        | 11/60 [00:17<01:14,  1.52s/it]
# Avg Confidence: 2.02, Avg Minimum Dist: 11.079:  18%|█▊        | 11/60 [00:19<01:14,  1.52s/it]
# Avg Confidence: 2.02, Avg Minimum Dist: 11.079:  18%|█▊        | 11/60 [00:19<01:14,  1.52s/it]
# Avg Confidence: 2.02, Avg Minimum Dist: 11.079:  20%|██        | 12/60 [00:19<01:13,  1.53s/it]
# Avg Confidence: 2.017, Avg Minimum Dist: 11.034:  20%|██        | 12/60 [00:20<01:13,  1.53s/it]
# Avg Confidence: 2.017, Avg Minimum Dist: 11.034:  20%|██        | 12/60 [00:20<01:13,  1.53s/it]
# Avg Confidence: 2.017, Avg Minimum Dist: 11.034:  22%|██▏       | 13/60 [00:20<01:14,  1.59s/it]
# Avg Confidence: 2.101, Avg Minimum Dist: 10.998:  22%|██▏       | 13/60 [00:22<01:14,  1.59s/it]
# Avg Confidence: 2.101, Avg Minimum Dist: 10.998:  22%|██▏       | 13/60 [00:22<01:14,  1.59s/it]
# Avg Confidence: 2.101, Avg Minimum Dist: 10.998:  23%|██▎       | 14/60 [00:22<01:14,  1.63s/it]
# Avg Confidence: 2.17, Avg Minimum Dist: 10.912:  23%|██▎       | 14/60 [00:23<01:14,  1.63s/it]
# Avg Confidence: 2.17, Avg Minimum Dist: 10.912:  23%|██▎       | 14/60 [00:23<01:14,  1.63s/it]
# Avg Confidence: 2.17, Avg Minimum Dist: 10.912:  25%|██▌       | 15/60 [00:23<01:08,  1.52s/it]
# Avg Confidence: 2.324, Avg Minimum Dist: 10.852:  25%|██▌       | 15/60 [00:25<01:08,  1.52s/it]
# Avg Confidence: 2.324, Avg Minimum Dist: 10.852:  25%|██▌       | 15/60 [00:25<01:08,  1.52s/it]
# Avg Confidence: 2.324, Avg Minimum Dist: 10.852:  27%|██▋       | 16/60 [00:25<01:07,  1.53s/it]
# Avg Confidence: 2.446, Avg Minimum Dist: 10.723:  27%|██▋       | 16/60 [00:26<01:07,  1.53s/it]
# Avg Confidence: 2.446, Avg Minimum Dist: 10.723:  27%|██▋       | 16/60 [00:26<01:07,  1.53s/it]
# Avg Confidence: 2.446, Avg Minimum Dist: 10.723:  28%|██▊       | 17/60 [00:26<01:02,  1.45s/it]
# Avg Confidence: 2.373, Avg Minimum Dist: 10.82:  28%|██▊       | 17/60 [00:27<01:02,  1.45s/it]
# Avg Confidence: 2.373, Avg Minimum Dist: 10.82:  28%|██▊       | 17/60 [00:27<01:02,  1.45s/it]
# Avg Confidence: 2.373, Avg Minimum Dist: 10.82:  30%|███       | 18/60 [00:27<00:59,  1.42s/it]
# Avg Confidence: 2.268, Avg Minimum Dist: 10.837:  30%|███       | 18/60 [00:29<00:59,  1.42s/it]
# Avg Confidence: 2.268, Avg Minimum Dist: 10.837:  30%|███       | 18/60 [00:29<00:59,  1.42s/it]
# Avg Confidence: 2.268, Avg Minimum Dist: 10.837:  32%|███▏      | 19/60 [00:29<01:04,  1.58s/it]
# Avg Confidence: 2.303, Avg Minimum Dist: 10.769:  32%|███▏      | 19/60 [00:31<01:04,  1.58s/it]
# Avg Confidence: 2.303, Avg Minimum Dist: 10.769:  32%|███▏      | 19/60 [00:31<01:04,  1.58s/it]
# Avg Confidence: 2.303, Avg Minimum Dist: 10.769:  33%|███▎      | 20/60 [00:31<01:01,  1.53s/it]
# Avg Confidence: 2.419, Avg Minimum Dist: 10.72:  33%|███▎      | 20/60 [00:32<01:01,  1.53s/it]
# Avg Confidence: 2.419, Avg Minimum Dist: 10.72:  33%|███▎      | 20/60 [00:32<01:01,  1.53s/it]
# Avg Confidence: 2.419, Avg Minimum Dist: 10.72:  35%|███▌      | 21/60 [00:32<00:57,  1.48s/it]
# Avg Confidence: 2.377, Avg Minimum Dist: 10.729:  35%|███▌      | 21/60 [00:33<00:57,  1.48s/it]
# Avg Confidence: 2.377, Avg Minimum Dist: 10.729:  35%|███▌      | 21/60 [00:33<00:57,  1.48s/it]
# Avg Confidence: 2.377, Avg Minimum Dist: 10.729:  37%|███▋      | 22/60 [00:33<00:53,  1.41s/it]
# Avg Confidence: 2.376, Avg Minimum Dist: 10.621:  37%|███▋      | 22/60 [00:36<00:53,  1.41s/it]
# Avg Confidence: 2.376, Avg Minimum Dist: 10.621:  37%|███▋      | 22/60 [00:36<00:53,  1.41s/it]
# Avg Confidence: 2.376, Avg Minimum Dist: 10.621:  38%|███▊      | 23/60 [00:36<01:03,  1.72s/it]
# Avg Confidence: 2.409, Avg Minimum Dist: 10.568:  38%|███▊      | 23/60 [00:37<01:03,  1.72s/it]
# Avg Confidence: 2.409, Avg Minimum Dist: 10.568:  38%|███▊      | 23/60 [00:37<01:03,  1.72s/it]
# Avg Confidence: 2.409, Avg Minimum Dist: 10.568:  40%|████      | 24/60 [00:37<00:59,  1.64s/it]
# Avg Confidence: 2.465, Avg Minimum Dist: 10.515:  40%|████      | 24/60 [00:39<00:59,  1.64s/it]
# Avg Confidence: 2.465, Avg Minimum Dist: 10.515:  40%|████      | 24/60 [00:39<00:59,  1.64s/it]
# Avg Confidence: 2.465, Avg Minimum Dist: 10.515:  42%|████▏     | 25/60 [00:39<00:54,  1.57s/it]
# Avg Confidence: 2.499, Avg Minimum Dist: 10.499:  42%|████▏     | 25/60 [00:41<00:54,  1.57s/it]
# Avg Confidence: 2.499, Avg Minimum Dist: 10.499:  42%|████▏     | 25/60 [00:41<00:54,  1.57s/it]
# Avg Confidence: 2.499, Avg Minimum Dist: 10.499:  43%|████▎     | 26/60 [00:41<00:57,  1.68s/it]
# Avg Confidence: 2.529, Avg Minimum Dist: 10.547:  43%|████▎     | 26/60 [00:43<00:57,  1.68s/it]
# Avg Confidence: 2.529, Avg Minimum Dist: 10.547:  43%|████▎     | 26/60 [00:43<00:57,  1.68s/it]
# Avg Confidence: 2.529, Avg Minimum Dist: 10.547:  45%|████▌     | 27/60 [00:43<00:57,  1.73s/it]
# Avg Confidence: 2.519, Avg Minimum Dist: 10.561:  45%|████▌     | 27/60 [00:44<00:57,  1.73s/it]
# Avg Confidence: 2.519, Avg Minimum Dist: 10.561:  45%|████▌     | 27/60 [00:44<00:57,  1.73s/it]
# Avg Confidence: 2.519, Avg Minimum Dist: 10.561:  47%|████▋     | 28/60 [00:44<00:55,  1.74s/it]
# Avg Confidence: 2.539, Avg Minimum Dist: 10.561:  47%|████▋     | 28/60 [00:46<00:55,  1.74s/it]
# Avg Confidence: 2.539, Avg Minimum Dist: 10.561:  47%|████▋     | 28/60 [00:46<00:55,  1.74s/it]
# Avg Confidence: 2.539, Avg Minimum Dist: 10.561:  48%|████▊     | 29/60 [00:46<00:50,  1.62s/it]
# Avg Confidence: 2.473, Avg Minimum Dist: 10.554:  48%|████▊     | 29/60 [00:47<00:50,  1.62s/it]
# Avg Confidence: 2.473, Avg Minimum Dist: 10.554:  48%|████▊     | 29/60 [00:47<00:50,  1.62s/it]
# Avg Confidence: 2.473, Avg Minimum Dist: 10.554:  50%|█████     | 30/60 [00:47<00:49,  1.64s/it]
# Avg Confidence: 2.417, Avg Minimum Dist: 10.564:  50%|█████     | 30/60 [00:49<00:49,  1.64s/it]
# Avg Confidence: 2.417, Avg Minimum Dist: 10.564:  50%|█████     | 30/60 [00:49<00:49,  1.64s/it]
# Avg Confidence: 2.417, Avg Minimum Dist: 10.564:  52%|█████▏    | 31/60 [00:49<00:48,  1.66s/it]
# Avg Confidence: 2.358, Avg Minimum Dist: 10.573:  52%|█████▏    | 31/60 [00:50<00:48,  1.66s/it]
# Avg Confidence: 2.358, Avg Minimum Dist: 10.573:  52%|█████▏    | 31/60 [00:50<00:48,  1.66s/it]
# Avg Confidence: 2.358, Avg Minimum Dist: 10.573:  53%|█████▎    | 32/60 [00:50<00:44,  1.58s/it]
# Avg Confidence: 2.364, Avg Minimum Dist: 10.518:  53%|█████▎    | 32/60 [00:52<00:44,  1.58s/it]
# Avg Confidence: 2.364, Avg Minimum Dist: 10.518:  53%|█████▎    | 32/60 [00:52<00:44,  1.58s/it]
# Avg Confidence: 2.364, Avg Minimum Dist: 10.518:  55%|█████▌    | 33/60 [00:52<00:40,  1.51s/it]
# Avg Confidence: 2.364, Avg Minimum Dist: 10.517:  55%|█████▌    | 33/60 [00:53<00:40,  1.51s/it]
# Avg Confidence: 2.364, Avg Minimum Dist: 10.517:  55%|█████▌    | 33/60 [00:53<00:40,  1.51s/it]
# Avg Confidence: 2.364, Avg Minimum Dist: 10.517:  57%|█████▋    | 34/60 [00:53<00:40,  1.56s/it]
# Avg Confidence: 2.407, Avg Minimum Dist: 10.462:  57%|█████▋    | 34/60 [00:55<00:40,  1.56s/it]
# Avg Confidence: 2.407, Avg Minimum Dist: 10.462:  57%|█████▋    | 34/60 [00:55<00:40,  1.56s/it]
# Avg Confidence: 2.407, Avg Minimum Dist: 10.462:  58%|█████▊    | 35/60 [00:55<00:39,  1.57s/it]
# Avg Confidence: 2.429, Avg Minimum Dist: 10.424:  58%|█████▊    | 35/60 [00:56<00:39,  1.57s/it]
# Avg Confidence: 2.429, Avg Minimum Dist: 10.424:  58%|█████▊    | 35/60 [00:56<00:39,  1.57s/it]
# Avg Confidence: 2.429, Avg Minimum Dist: 10.424:  60%|██████    | 36/60 [00:56<00:35,  1.49s/it]
# Avg Confidence: 2.421, Avg Minimum Dist: 10.439:  60%|██████    | 36/60 [00:58<00:35,  1.49s/it]
# Avg Confidence: 2.421, Avg Minimum Dist: 10.439:  60%|██████    | 36/60 [00:58<00:35,  1.49s/it]
# Avg Confidence: 2.421, Avg Minimum Dist: 10.439:  62%|██████▏   | 37/60 [00:58<00:33,  1.48s/it]
# Avg Confidence: 2.398, Avg Minimum Dist: 10.453:  62%|██████▏   | 37/60 [00:59<00:33,  1.48s/it]
# Avg Confidence: 2.398, Avg Minimum Dist: 10.453:  62%|██████▏   | 37/60 [00:59<00:33,  1.48s/it]
# Avg Confidence: 2.398, Avg Minimum Dist: 10.453:  63%|██████▎   | 38/60 [00:59<00:32,  1.50s/it]
# Avg Confidence: 2.358, Avg Minimum Dist: 10.461:  63%|██████▎   | 38/60 [01:01<00:32,  1.50s/it]
# Avg Confidence: 2.358, Avg Minimum Dist: 10.461:  63%|██████▎   | 38/60 [01:01<00:32,  1.50s/it]
# Avg Confidence: 2.358, Avg Minimum Dist: 10.461:  65%|██████▌   | 39/60 [01:01<00:31,  1.51s/it]
# Avg Confidence: 2.397, Avg Minimum Dist: 10.475:  65%|██████▌   | 39/60 [01:02<00:31,  1.51s/it]
# Avg Confidence: 2.397, Avg Minimum Dist: 10.475:  65%|██████▌   | 39/60 [01:02<00:31,  1.51s/it]
# Avg Confidence: 2.397, Avg Minimum Dist: 10.475:  67%|██████▋   | 40/60 [01:02<00:29,  1.46s/it]
# Avg Confidence: 2.363, Avg Minimum Dist: 10.52:  67%|██████▋   | 40/60 [01:04<00:29,  1.46s/it]
# Avg Confidence: 2.363, Avg Minimum Dist: 10.52:  67%|██████▋   | 40/60 [01:04<00:29,  1.46s/it]
# Avg Confidence: 2.363, Avg Minimum Dist: 10.52:  68%|██████▊   | 41/60 [01:04<00:27,  1.45s/it]
# Avg Confidence: 2.327, Avg Minimum Dist: 10.493:  68%|██████▊   | 41/60 [01:06<00:27,  1.45s/it]
# Avg Confidence: 2.327, Avg Minimum Dist: 10.493:  68%|██████▊   | 41/60 [01:06<00:27,  1.45s/it]
# Avg Confidence: 2.327, Avg Minimum Dist: 10.493:  70%|███████   | 42/60 [01:06<00:31,  1.73s/it]
# Avg Confidence: 2.339, Avg Minimum Dist: 10.473:  70%|███████   | 42/60 [01:07<00:31,  1.73s/it]
# Avg Confidence: 2.339, Avg Minimum Dist: 10.473:  70%|███████   | 42/60 [01:07<00:31,  1.73s/it]
# Avg Confidence: 2.339, Avg Minimum Dist: 10.473:  72%|███████▏  | 43/60 [01:07<00:27,  1.62s/it]
# Avg Confidence: 2.372, Avg Minimum Dist: 10.451:  72%|███████▏  | 43/60 [01:09<00:27,  1.62s/it]
# Avg Confidence: 2.372, Avg Minimum Dist: 10.451:  72%|███████▏  | 43/60 [01:09<00:27,  1.62s/it]
# Avg Confidence: 2.372, Avg Minimum Dist: 10.451:  73%|███████▎  | 44/60 [01:09<00:24,  1.53s/it]
# Avg Confidence: 2.357, Avg Minimum Dist: 10.475:  73%|███████▎  | 44/60 [01:10<00:24,  1.53s/it]
# Avg Confidence: 2.357, Avg Minimum Dist: 10.475:  73%|███████▎  | 44/60 [01:10<00:24,  1.53s/it]
# Avg Confidence: 2.357, Avg Minimum Dist: 10.475:  75%|███████▌  | 45/60 [01:10<00:22,  1.53s/it]
# Avg Confidence: 2.369, Avg Minimum Dist: 10.476:  75%|███████▌  | 45/60 [01:12<00:22,  1.53s/it]
# Avg Confidence: 2.369, Avg Minimum Dist: 10.476:  75%|███████▌  | 45/60 [01:12<00:22,  1.53s/it]
# Avg Confidence: 2.369, Avg Minimum Dist: 10.476:  77%|███████▋  | 46/60 [01:12<00:20,  1.50s/it]
# Avg Confidence: 2.329, Avg Minimum Dist: 10.516:  77%|███████▋  | 46/60 [01:14<00:20,  1.50s/it]
# Avg Confidence: 2.329, Avg Minimum Dist: 10.516:  77%|███████▋  | 46/60 [01:14<00:20,  1.50s/it]
# Avg Confidence: 2.329, Avg Minimum Dist: 10.516:  78%|███████▊  | 47/60 [01:14<00:22,  1.69s/it]
# Avg Confidence: 2.292, Avg Minimum Dist: 10.511:  78%|███████▊  | 47/60 [01:16<00:22,  1.69s/it]
# Avg Confidence: 2.292, Avg Minimum Dist: 10.511:  78%|███████▊  | 47/60 [01:16<00:22,  1.69s/it]
# Avg Confidence: 2.292, Avg Minimum Dist: 10.511:  80%|████████  | 48/60 [01:16<00:20,  1.72s/it]
# Avg Confidence: 2.287, Avg Minimum Dist: 10.52:  80%|████████  | 48/60 [01:17<00:20,  1.72s/it]
# Avg Confidence: 2.287, Avg Minimum Dist: 10.52:  80%|████████  | 48/60 [01:17<00:20,  1.72s/it]
# Avg Confidence: 2.287, Avg Minimum Dist: 10.52:  82%|████████▏ | 49/60 [01:17<00:17,  1.56s/it]
# Avg Confidence: 2.262, Avg Minimum Dist: 10.528:  82%|████████▏ | 49/60 [01:18<00:17,  1.56s/it]
# Avg Confidence: 2.262, Avg Minimum Dist: 10.528:  82%|████████▏ | 49/60 [01:18<00:17,  1.56s/it]
# Avg Confidence: 2.262, Avg Minimum Dist: 10.528:  83%|████████▎ | 50/60 [01:18<00:15,  1.58s/it]
# Avg Confidence: 2.272, Avg Minimum Dist: 10.509:  83%|████████▎ | 50/60 [01:20<00:15,  1.58s/it]
# Avg Confidence: 2.272, Avg Minimum Dist: 10.509:  83%|████████▎ | 50/60 [01:20<00:15,  1.58s/it]
# Avg Confidence: 2.272, Avg Minimum Dist: 10.509:  85%|████████▌ | 51/60 [01:20<00:13,  1.55s/it]
# Avg Confidence: 2.261, Avg Minimum Dist: 10.52:  85%|████████▌ | 51/60 [01:21<00:13,  1.55s/it]
# Avg Confidence: 2.261, Avg Minimum Dist: 10.52:  85%|████████▌ | 51/60 [01:21<00:13,  1.55s/it]
# Avg Confidence: 2.261, Avg Minimum Dist: 10.52:  87%|████████▋ | 52/60 [01:21<00:12,  1.54s/it]
# Avg Confidence: 2.328, Avg Minimum Dist: 10.486:  87%|████████▋ | 52/60 [01:23<00:12,  1.54s/it]
# Avg Confidence: 2.328, Avg Minimum Dist: 10.486:  87%|████████▋ | 52/60 [01:23<00:12,  1.54s/it]
# Avg Confidence: 2.328, Avg Minimum Dist: 10.486:  88%|████████▊ | 53/60 [01:23<00:11,  1.64s/it]
# Avg Confidence: 2.329, Avg Minimum Dist: 10.468:  88%|████████▊ | 53/60 [01:26<00:11,  1.64s/it]
# Avg Confidence: 2.329, Avg Minimum Dist: 10.468:  88%|████████▊ | 53/60 [01:26<00:11,  1.64s/it]
# Avg Confidence: 2.329, Avg Minimum Dist: 10.468:  90%|█████████ | 54/60 [01:26<00:11,  1.89s/it]
# Avg Confidence: 2.306, Avg Minimum Dist: 10.527:  90%|█████████ | 54/60 [01:28<00:11,  1.89s/it]
# Avg Confidence: 2.306, Avg Minimum Dist: 10.527:  90%|█████████ | 54/60 [01:28<00:11,  1.89s/it]
# Avg Confidence: 2.306, Avg Minimum Dist: 10.527:  92%|█████████▏| 55/60 [01:28<00:10,  2.01s/it]
# Avg Confidence: 2.293, Avg Minimum Dist: 10.514:  92%|█████████▏| 55/60 [01:30<00:10,  2.01s/it]
# Avg Confidence: 2.293, Avg Minimum Dist: 10.514:  92%|█████████▏| 55/60 [01:30<00:10,  2.01s/it]
# Avg Confidence: 2.293, Avg Minimum Dist: 10.514:  93%|█████████▎| 56/60 [01:30<00:07,  1.94s/it]
# Avg Confidence: 2.266, Avg Minimum Dist: 10.5:  93%|█████████▎| 56/60 [01:32<00:07,  1.94s/it]
# Avg Confidence: 2.266, Avg Minimum Dist: 10.5:  93%|█████████▎| 56/60 [01:32<00:07,  1.94s/it]
# Avg Confidence: 2.266, Avg Minimum Dist: 10.5:  95%|█████████▌| 57/60 [01:32<00:05,  1.94s/it]
# Avg Confidence: 2.233, Avg Minimum Dist: 10.504:  95%|█████████▌| 57/60 [01:34<00:05,  1.94s/it]
# Avg Confidence: 2.233, Avg Minimum Dist: 10.504:  95%|█████████▌| 57/60 [01:34<00:05,  1.94s/it]
# Avg Confidence: 2.233, Avg Minimum Dist: 10.504:  97%|█████████▋| 58/60 [01:34<00:04,  2.18s/it]
# Avg Confidence: 2.198, Avg Minimum Dist: 10.537:  97%|█████████▋| 58/60 [01:36<00:04,  2.18s/it]
# Avg Confidence: 2.198, Avg Minimum Dist: 10.537:  97%|█████████▋| 58/60 [01:36<00:04,  2.18s/it]
# Avg Confidence: 2.198, Avg Minimum Dist: 10.537:  98%|█████████▊| 59/60 [01:36<00:02,  2.10s/it]
# Avg Confidence: 2.233, Avg Minimum Dist: 10.512:  98%|█████████▊| 59/60 [01:38<00:02,  2.10s/it]
# Avg Confidence: 2.233, Avg Minimum Dist: 10.512:  98%|█████████▊| 59/60 [01:38<00:02,  2.10s/it]
# Avg Confidence: 2.233, Avg Minimum Dist: 10.512: 100%|██████████| 60/60 [01:38<00:00,  2.06s/it]
# Avg Confidence: 2.233, Avg Minimum Dist: 10.512: 100%|██████████| 60/60 [01:38<00:00,  1.65s/it]
#
#
# VCTK Results:
#   Average Confidence (LSE-C): 2.2330
#   Average Minimum Distance (LSE-D): 10.5118
#
# VCTK Overall Scores:
#   LSE-C (Confidence): 2.2330
#   LSE-D (Distance): 10.5118
#
# ============================================================
# LSE EVALUATION COMPLETE
# ============================================================
#
# Individual Results:
# dataset speaker_id tts_method  lse_d_score  lse_c_score
#     RAW       A015  CosyVoice    11.338537     2.715018
#     RAW       S011    YourTTS    11.338537     2.715018
#     RAW       A016    YourTTS    11.338537     2.715018
#     RAW       A017  CosyVoice    11.338537     2.715018
#     RAW       A010     XTTSv2    11.338537     2.715018
#     RAW       S003  CosyVoice    11.338537     2.715018
#     RAW       A008    YourTTS    11.338537     2.715018
#     RAW       A006    YourTTS    11.338537     2.715018
#     RAW       S012    YourTTS    11.338537     2.715018
#     RAW       S007     XTTSv2    11.338537     2.715018
#     RAW       A014  CosyVoice    11.338537     2.715018
#     RAW       S002     XTTSv2    11.338537     2.715018
#     RAW       S009     XTTSv2    11.338537     2.715018
#     RAW       S013  CosyVoice    11.338537     2.715018
#     RAW       A011  CosyVoice    11.338537     2.715018
#     RAW       A016     XTTSv2    11.338537     2.715018
#     RAW       S005  CosyVoice    11.338537     2.715018
#     RAW       A002  CosyVoice    11.338537     2.715018
#     RAW       S011     XTTSv2    11.338537     2.715018
#     RAW       S002  CosyVoice    11.338537     2.715018
#     RAW       A010    YourTTS    11.338537     2.715018
#     RAW       A015     XTTSv2    11.338537     2.715018
#     RAW       S012     XTTSv2    11.338537     2.715018
#     RAW       S008  CosyVoice    11.338537     2.715018
#     RAW       A006     XTTSv2    11.338537     2.715018
#     RAW       S006  CosyVoice    11.338537     2.715018
#     RAW       A008     XTTSv2    11.338537     2.715018
#     RAW       S001    YourTTS    11.338537     2.715018
#     RAW       S009    YourTTS    11.338537     2.715018
#     RAW       S007    YourTTS    11.338537     2.715018
#     RAW       S011  CosyVoice    11.338537     2.715018
#     RAW       A002     XTTSv2    11.338537     2.715018
#     RAW       S005     XTTSv2    11.338537     2.715018
#     RAW       A016  CosyVoice    11.338537     2.715018
#     RAW       A011     XTTSv2    11.338537     2.715018
#     RAW       S002    YourTTS    11.338537     2.715018
#     RAW       A017    YourTTS    11.338537     2.715018
#     RAW       S003    YourTTS    11.338537     2.715018
#     RAW       A008  CosyVoice    11.338537     2.715018
#     RAW       S006     XTTSv2    11.338537     2.715018
#     RAW       A006  CosyVoice    11.338537     2.715018
#     RAW       S012  CosyVoice    11.338537     2.715018
#     RAW       S008     XTTSv2    11.338537     2.715018
#     RAW       S001  CosyVoice    11.338537     2.715018
#     RAW       A014    YourTTS    11.338537     2.715018
#     RAW       S013    YourTTS    11.338537     2.715018
#     RAW       A011    YourTTS    11.338537     2.715018
#     RAW       S005    YourTTS    11.338537     2.715018
#     RAW       A002    YourTTS    11.338537     2.715018
#     RAW       S003     XTTSv2    11.338537     2.715018
#     RAW       A010  CosyVoice    11.338537     2.715018
#     RAW       A017     XTTSv2    11.338537     2.715018
#     RAW       S001     XTTSv2    11.338537     2.715018
#     RAW       S008    YourTTS    11.338537     2.715018
#     RAW       S006    YourTTS    11.338537     2.715018
#     RAW       A015    YourTTS    11.338537     2.715018
#     RAW       S009  CosyVoice    11.338537     2.715018
#     RAW       S013     XTTSv2    11.338537     2.715018
#     RAW       A014     XTTSv2    11.338537     2.715018
#     RAW       S007  CosyVoice    11.338537     2.715018
#    VCTK       S013  CosyVoice    10.511788     2.233048
#    VCTK       S012    YourTTS    10.511788     2.233048
#    VCTK       A010  CosyVoice    10.511788     2.233048
#    VCTK       A011    YourTTS    10.511788     2.233048
#    VCTK       A002  CosyVoice    10.511788     2.233048
#    VCTK       S012  CosyVoice    10.511788     2.233048
#    VCTK       S013    YourTTS    10.511788     2.233048
#    VCTK       S003     XTTSv2    10.511788     2.233048
#    VCTK       A011  CosyVoice    10.511788     2.233048
#    VCTK       A010    YourTTS    10.511788     2.233048
#    VCTK       A002    YourTTS    10.511788     2.233048
#    VCTK       S011     XTTSv2    10.511788     2.233048
#    VCTK       S012     XTTSv2    10.511788     2.233048
#    VCTK       S003  CosyVoice    10.511788     2.233048
#    VCTK       A011     XTTSv2    10.511788     2.233048
#    VCTK       S011  CosyVoice    10.511788     2.233048
#    VCTK       S003    YourTTS    10.511788     2.233048
#    VCTK       S013     XTTSv2    10.511788     2.233048
#    VCTK       A010     XTTSv2    10.511788     2.233048
#    VCTK       A002     XTTSv2    10.511788     2.233048
#    VCTK       S011    YourTTS    10.511788     2.233048
#    VCTK       S001     XTTSv2    10.511788     2.233048
#    VCTK       A014  CosyVoice    10.511788     2.233048
#    VCTK       S009    YourTTS    10.511788     2.233048
#    VCTK       S008  CosyVoice    10.511788     2.233048
#    VCTK       S006     XTTSv2    10.511788     2.233048
#    VCTK       S002  CosyVoice    10.511788     2.233048
#    VCTK       S005  CosyVoice    10.511788     2.233048
#    VCTK       A008     XTTSv2    10.511788     2.233048
#    VCTK       A006  CosyVoice    10.511788     2.233048
#    VCTK       A017     XTTSv2    10.511788     2.233048
#    VCTK       A015     XTTSv2    10.511788     2.233048
#    VCTK       A014    YourTTS    10.511788     2.233048
#    VCTK       S007     XTTSv2    10.511788     2.233048
#    VCTK       S008    YourTTS    10.511788     2.233048
#    VCTK       S009  CosyVoice    10.511788     2.233048
#    VCTK       S005    YourTTS    10.511788     2.233048
#    VCTK       A016     XTTSv2    10.511788     2.233048
#    VCTK       A006    YourTTS    10.511788     2.233048
#    VCTK       S002    YourTTS    10.511788     2.233048
#    VCTK       S001    YourTTS    10.511788     2.233048
#    VCTK       A015  CosyVoice    10.511788     2.233048
#    VCTK       S009     XTTSv2    10.511788     2.233048
#    VCTK       S006    YourTTS    10.511788     2.233048
#    VCTK       S007  CosyVoice    10.511788     2.233048
#    VCTK       A008    YourTTS    10.511788     2.233048
#    VCTK       A016  CosyVoice    10.511788     2.233048
#    VCTK       A017    YourTTS    10.511788     2.233048
#    VCTK       S001  CosyVoice    10.511788     2.233048
#    VCTK       A015    YourTTS    10.511788     2.233048
#    VCTK       A014     XTTSv2    10.511788     2.233048
#    VCTK       S007    YourTTS    10.511788     2.233048
#    VCTK       S006  CosyVoice    10.511788     2.233048
#    VCTK       S008     XTTSv2    10.511788     2.233048
#    VCTK       S002     XTTSv2    10.511788     2.233048
#    VCTK       S005     XTTSv2    10.511788     2.233048
#    VCTK       A006     XTTSv2    10.511788     2.233048
#    VCTK       A017  CosyVoice    10.511788     2.233048
#    VCTK       A016    YourTTS    10.511788     2.233048
#    VCTK       A008  CosyVoice    10.511788     2.233048
#
# ============================================================
# AVERAGES PER DATASET AND TTS METHOD
# ============================================================
#
# RAW - CosyVoice (20 samples):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW - XTTSv2 (20 samples):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW - YourTTS (20 samples):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# VCTK - CosyVoice (20 samples):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK - XTTSv2 (20 samples):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK - YourTTS (20 samples):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# ============================================================
# AVERAGES PER SPEAKER
# ============================================================
#
# RAW_A002 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_A006 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_A008 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_A010 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_A011 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_A014 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_A015 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_A016 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_A017 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_S001 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_S002 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_S003 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_S005 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_S006 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_S007 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_S008 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_S009 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_S011 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_S012 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# RAW_S013 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# VCTK_A002 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_A006 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_A008 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_A010 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_A011 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_A014 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_A015 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_A016 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_A017 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_S001 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_S002 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_S003 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_S005 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_S006 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_S007 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_S008 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_S009 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_S011 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_S012 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# VCTK_S013 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# ============================================================
# SUMMARY TABLES
# ============================================================
#
# Summary by Dataset and TTS Method:
# Dataset TTS_Method  Count  LSE_D_Mean  LSE_D_Std  LSE_C_Mean  LSE_C_Std
#     RAW  CosyVoice     20     11.3385        0.0       2.715        0.0
#     RAW     XTTSv2     20     11.3385        0.0       2.715        0.0
#     RAW    YourTTS     20     11.3385        0.0       2.715        0.0
#    VCTK  CosyVoice     20     10.5118        0.0       2.233        0.0
#    VCTK     XTTSv2     20     10.5118        0.0       2.233        0.0
#    VCTK    YourTTS     20     10.5118        0.0       2.233        0.0
#
# Summary by Speaker:
# Dataset Speaker_ID  Count  LSE_D_Mean  LSE_D_Std  LSE_C_Mean  LSE_C_Std                TTS_Methods
#     RAW       A002      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       A006      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       A008      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       A010      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       A011      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       A014      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       A015      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       A016      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       A017      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       S001      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       S002      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       S003      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       S005      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       S006      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       S007      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       S008      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       S009      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       S011      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       S012      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       S013      3     11.3385        0.0       2.715        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       A002      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       A006      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       A008      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       A010      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       A011      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       A014      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       A015      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       A016      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       A017      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       S001      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       S002      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       S003      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       S005      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       S006      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       S007      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       S008      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       S009      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       S011      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       S012      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       S013      3     10.5118        0.0       2.233        0.0 XTTSv2, CosyVoice, YourTTS
#
# ============================================================
# OVERALL STATISTICS PER DATASET
# ============================================================
#
# RAW Dataset:
#   Total samples: 60
#   LSE-D: 11.3385 ± 0.0000
#   LSE-C: 2.7150 ± 0.0000
#
# VCTK Dataset:
#   Total samples: 60
#   LSE-D: 10.5118 ± 0.0000
#   LSE-C: 2.2330 ± 0.0000
#
# Detailed results saved to: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_results_lse.csv
# TTS summary saved to: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_summary_lse_tts.csv
# Speaker summary saved to: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_summary_lse_speaker.csv
#
# LSE evaluation completed successfully!

# %%
import warnings
import os
import pandas as pd
import numpy as np
import subprocess
import glob
import shutil
from collections import defaultdict

# Suppress warnings
warnings.filterwarnings('ignore')
os.environ['PYTHONWARNINGS'] = 'ignore'

def extract_info_from_edtalk_filename(filename):
    """Extract speaker ID and TTS method from EDTalk filename"""
    basename = os.path.basename(filename)
    
    # Extract TTS method
    if "_CV_" in basename:
        tts_method = "CosyVoice"
    elif "_XT_" in basename:
        tts_method = "XTTSv2"
    elif "_YT_" in basename:
        tts_method = "YourTTS"
    else:
        tts_method = "Unknown"
    
    # Extract speaker ID (first part)
    speaker_id = basename.split('_')[0]  # A002, A006, S001, etc.
    
    # Check if it's avatar or not
    is_avatar = "_avatar_" in basename
    
    return speaker_id, tts_method, is_avatar

def create_temp_folder_with_512_files(video_folder, dataset_name):
    """Create temporary folder containing only 512 resolution files for LSE calculation"""
    temp_folder = f"temp_512_{dataset_name}"
    
    # Clean up if exists
    if os.path.exists(temp_folder):
        shutil.rmtree(temp_folder)
    
    # Create temp folder
    os.makedirs(temp_folder, exist_ok=True)
    
    # Get all 512.mp4 files
    video_files_512 = glob.glob(os.path.join(video_folder, "*_512.mp4"))
    
    # Copy 512 files to temp folder
    for video_file in video_files_512:
        basename = os.path.basename(video_file)
        temp_path = os.path.join(temp_folder, basename)
        shutil.copy2(video_file, temp_path)
    
    print(f"Created temp folder with {len(video_files_512)} files")
    return temp_folder, video_files_512

def calculate_lse_batch(video_folder, dataset_name):
    """Calculate LSE scores for 512 resolution videos only using calculate_scores_LRS.py"""
    print(f"Calculating LSE scores for {dataset_name} videos in: {video_folder}")
    
    # Create temp folder with only 512 files
    temp_512_folder, video_files_512 = create_temp_folder_with_512_files(video_folder, dataset_name)
    
    if len(video_files_512) == 0:
        print(f"No 512 resolution files found in {video_folder}")
        return None, None, []
    
    # Create temporary directory for calculation
    tmp_dir = f"tmp_dir_{dataset_name}"
    
    try:
        # Run syncnet evaluation using calculate_scores_LRS.py on temp folder
        cmd = [
            'python', 'calculate_scores_LRS.py', 
            '--data_root', temp_512_folder,
            '--tmp_dir', tmp_dir
        ]
        
        # Suppress warnings
        env = os.environ.copy()
        env['PYTHONWARNINGS'] = 'ignore'
        
        print(f"Running command: {' '.join(cmd)}")
        result = subprocess.run(cmd, capture_output=True, text=True, env=env)
        
        print("STDOUT:", result.stdout)
        if result.stderr:
            print("STDERR:", result.stderr)
        
        # Parse results from stdout
        output_lines = result.stdout.split('\n')
        
        avg_confidence = None
        avg_min_distance = None
        
        for line in output_lines:
            if 'Average Confidence:' in line:
                try:
                    avg_confidence = float(line.split('Average Confidence:')[1].strip())
                except:
                    pass
            if 'Average Minimum Distance:' in line:
                try:
                    avg_min_distance = float(line.split('Average Minimum Distance:')[1].strip())
                except:
                    pass

        print(f"\n{dataset_name} Results:")
        print(f"  Average Confidence (LSE-C): {avg_confidence:.4f}" if avg_confidence else "  LSE-C: Not found")
        print(f"  Average Minimum Distance (LSE-D): {avg_min_distance:.4f}" if avg_min_distance else "  LSE-D: Not found")
        
        return avg_confidence, avg_min_distance, video_files_512
            
    except Exception as e:
        print(f"Error running syncnet: {e}")
        return None, None, []
    finally:
        # Clean up temporary directories
        if os.path.exists(tmp_dir):
            shutil.rmtree(tmp_dir)
        if os.path.exists(temp_512_folder):
            shutil.rmtree(temp_512_folder)

# Define video folders to evaluate for EDTalk
video_folders = [
    # Non-avatar (v15) results
    "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/edtalk-exp/EDTalk/results/test_raw/v15/RAW",
    "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/edtalk-exp/EDTalk/results/test_vctk/v15/VCTK",
    # Avatar results
    "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/edtalk-exp/EDTalk/results/test_raw/avatar/RAW",
    "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/edtalk-exp/EDTalk/results/test_vctk/avatar/VCTK"
]

dataset_names = ["RAW_v15", "VCTK_v15", "RAW_avatar", "VCTK_avatar"]

all_results = []
lse_d_scores = defaultdict(list)
lse_c_scores = defaultdict(list)
speaker_scores = defaultdict(lambda: defaultdict(list))

print("Starting LSE evaluation for EDTalk results...")
print("=" * 70)

for dataset_name, video_folder in zip(dataset_names, video_folders):
    if not os.path.exists(video_folder):
        print(f"Warning: Video folder not found: {video_folder}")
        continue
    
    print(f"\nProcessing {dataset_name} dataset...")
    print(f"Folder: {video_folder}")
    
    # Calculate LSE scores for this dataset (512 files only)
    lse_c, lse_d, video_files_512 = calculate_lse_batch(video_folder, dataset_name)
    
    if lse_c is not None and lse_d is not None and len(video_files_512) > 0:
        print(f"\n{dataset_name} Overall Scores:")
        print(f"  LSE-C (Confidence): {lse_c:.4f}")
        print(f"  LSE-D (Distance): {lse_d:.4f}")
        print(f"  Total 512 res files processed: {len(video_files_512)}")
        
        # Show first few files
        print("Sample files processed:")
        for i, vf in enumerate(video_files_512[:5]):
            print(f"  {i+1}. {os.path.basename(vf)}")
        
        # Process each 512 video file to get individual info
        for video_file in video_files_512:
            speaker_id, tts_method, is_avatar = extract_info_from_edtalk_filename(video_file)
            
            # Determine data type
            data_type = "Avatar" if "avatar" in dataset_name else "V15"
            base_dataset = dataset_name.split('_')[0]  # RAW or VCTK
            
            # Store individual result
            result = {
                'dataset': base_dataset,
                'data_type': data_type,
                'speaker_id': speaker_id,
                'tts_method': tts_method,
                'is_avatar': is_avatar,
                'lse_d_score': lse_d,
                'lse_c_score': lse_c,
                'video_file': os.path.basename(video_file)
            }
            all_results.append(result)
            
            # Store for averaging by dataset and TTS method
            key = f"{dataset_name}_{tts_method}"
            lse_d_scores[key].append(lse_d)
            lse_c_scores[key].append(lse_c)
            
            # Store for averaging by speaker
            speaker_key = f"{dataset_name}_{speaker_id}"
            speaker_scores[speaker_key]['lse_d'].append(lse_d)
            speaker_scores[speaker_key]['lse_c'].append(lse_c)
            speaker_scores[speaker_key]['tts_methods'].append(tts_method)
    else:
        print(f"Failed to get LSE scores for {dataset_name} or no files found")

print("\n" + "=" * 70)
print("EDTalk LSE EVALUATION COMPLETE")
print("=" * 70)

# Convert to DataFrame
df = pd.DataFrame(all_results)

# Display results
if len(df) > 0:
    print("\nIndividual Results:")
    print(df[['dataset', 'data_type', 'speaker_id', 'tts_method', 'lse_d_score', 'lse_c_score']].to_string(index=False))
    
    # Averages per dataset, data_type and TTS method
    print("\n" + "=" * 70)
    print("AVERAGES PER DATASET, DATA TYPE AND TTS METHOD")
    print("=" * 70)
    
    tts_summary_data = []
    for dataset in ['RAW', 'VCTK']:
        for data_type in ['v15', 'avatar']:
            for tts_method in ['CosyVoice', 'XTTSv2', 'YourTTS']:
                key = f"{dataset}_{data_type}_{tts_method}"
                if key in lse_d_scores and len(lse_d_scores[key]) > 0:
                    avg_lse_d = np.mean(lse_d_scores[key])
                    std_lse_d = np.std(lse_d_scores[key])
                    avg_lse_c = np.mean(lse_c_scores[key])
                    std_lse_c = np.std(lse_c_scores[key])
                    count = len(lse_d_scores[key])
                    
                    print(f"\n{dataset} - {data_type} - {tts_method} ({count} samples):")
                    print(f"  LSE-D: {avg_lse_d:.4f} ± {std_lse_d:.4f}")
                    print(f"  LSE-C: {avg_lse_c:.4f} ± {std_lse_c:.4f}")
                    
                    tts_summary_data.append({
                        'Dataset': dataset,
                        'Data_Type': data_type,
                        'TTS_Method': tts_method,
                        'Count': count,
                        'LSE_D_Mean': avg_lse_d,
                        'LSE_D_Std': std_lse_d,
                        'LSE_C_Mean': avg_lse_c,
                        'LSE_C_Std': std_lse_c
                    })
    
    # Averages per speaker
    print("\n" + "=" * 70)
    print("AVERAGES PER SPEAKER")
    print("=" * 70)
    
    speaker_summary_data = []
    for speaker_key in sorted(speaker_scores.keys()):
        if len(speaker_scores[speaker_key]['lse_d']) > 0:
            avg_lse_d = np.mean(speaker_scores[speaker_key]['lse_d'])
            std_lse_d = np.std(speaker_scores[speaker_key]['lse_d'])
            avg_lse_c = np.mean(speaker_scores[speaker_key]['lse_c'])
            std_lse_c = np.std(speaker_scores[speaker_key]['lse_c'])
            count = len(speaker_scores[speaker_key]['lse_d'])
            
            tts_methods = list(set(speaker_scores[speaker_key]['tts_methods']))
            parts = speaker_key.split('_')
            dataset_name = parts[0]
            data_type = parts[1]
            speaker_id = '_'.join(parts[2:])
            
            print(f"\n{speaker_key} ({count} samples, TTS: {', '.join(tts_methods)}):")
            print(f"  LSE-D: {avg_lse_d:.4f} ± {std_lse_d:.4f}")
            print(f"  LSE-C: {avg_lse_c:.4f} ± {std_lse_c:.4f}")
            
            speaker_summary_data.append({
                'Dataset': dataset_name,
                'Data_Type': data_type,
                'Speaker_ID': speaker_id,
                'Count': count,
                'LSE_D_Mean': avg_lse_d,
                'LSE_D_Std': std_lse_d,
                'LSE_C_Mean': avg_lse_c,
                'LSE_C_Std': std_lse_c,
                'TTS_Methods': ', '.join(tts_methods)
            })
    
    # Create and display summary tables
    print("\n" + "=" * 70)
    print("SUMMARY TABLES")
    print("=" * 70)
    
    # TTS Method Summary
    tts_summary_df = pd.DataFrame(tts_summary_data)
    print("\nSummary by Dataset, Data Type and TTS Method:")
    print(tts_summary_df.round(4).to_string(index=False))
    
    # Speaker Summary
    speaker_summary_df = pd.DataFrame(speaker_summary_data)
    print("\nSummary by Speaker:")
    print(speaker_summary_df.round(4).to_string(index=False))
    
    # Overall statistics per dataset and data type
    print("\n" + "=" * 70)
    print("OVERALL STATISTICS PER DATASET AND DATA TYPE")
    print("=" * 70)
    
    for dataset in ['RAW', 'VCTK']:
        for data_type in ['V15', 'Avatar']:
            dataset_results = df[(df['dataset'] == dataset) & (df['data_type'] == data_type)]
            if len(dataset_results) > 0:
                avg_lse_d = dataset_results['lse_d_score'].mean()
                std_lse_d = dataset_results['lse_d_score'].std()
                avg_lse_c = dataset_results['lse_c_score'].mean()
                std_lse_c = dataset_results['lse_c_score'].std()
                
                print(f"\n{dataset} - {data_type} Dataset (512 resolution):")
                print(f"  Total samples: {len(dataset_results)}")
                print(f"  LSE-D: {avg_lse_d:.4f} ± {std_lse_d:.4f}")
                print(f"  LSE-C: {avg_lse_c:.4f} ± {std_lse_c:.4f}")
    
    # Comparison between Avatar and V15
    print("\n" + "=" * 70)
    print("AVATAR vs V15 COMPARISON")
    print("=" * 70)
    
    comparison_data = []
    for dataset in ['RAW', 'VCTK']:
        for tts_method in ['CosyVoice', 'XTTSv2', 'YourTTS']:
            v15_results = df[(df['dataset'] == dataset) & (df['data_type'] == 'V15') & (df['tts_method'] == tts_method)]
            avatar_results = df[(df['dataset'] == dataset) & (df['data_type'] == 'Avatar') & (df['tts_method'] == tts_method)]
            
            if len(v15_results) > 0 and len(avatar_results) > 0:
                v15_lse_d = v15_results['lse_d_score'].mean()
                v15_lse_c = v15_results['lse_c_score'].mean()
                avatar_lse_d = avatar_results['lse_d_score'].mean()
                avatar_lse_c = avatar_results['lse_c_score'].mean()
                
                print(f"\n{dataset} - {tts_method}:")
                print(f"  V15    - LSE-D: {v15_lse_d:.4f}, LSE-C: {v15_lse_c:.4f}")
                print(f"  Avatar - LSE-D: {avatar_lse_d:.4f}, LSE-C: {avatar_lse_c:.4f}")
                print(f"  Improvement (D): {v15_lse_d - avatar_lse_d:+.4f}")
                print(f"  Improvement (C): {avatar_lse_c - v15_lse_c:+.4f}")
                
                comparison_data.append({
                    'Dataset': dataset,
                    'TTS_Method': tts_method,
                    'V15_LSE_D': v15_lse_d,
                    'V15_LSE_C': v15_lse_c,
                    'Avatar_LSE_D': avatar_lse_d,
                    'Avatar_LSE_C': avatar_lse_c,
                    'LSE_D_Improvement': v15_lse_d - avatar_lse_d,
                    'LSE_C_Improvement': avatar_lse_c - v15_lse_c
                })
    
    comparison_df = pd.DataFrame(comparison_data)
    print("\nDetailed Avatar vs V15 Comparison:")
    print(comparison_df.round(4).to_string(index=False))
    
    # Save results to CSV
    output_path = "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_results_lse_edtalk.csv"
    df.to_csv(output_path, index=False)
    print(f"\nDetailed results saved to: {output_path}")
    
    # Save TTS summary
    tts_summary_output_path = "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_summary_lse_edtalk_tts.csv"
    tts_summary_df.to_csv(tts_summary_output_path, index=False)
    print(f"TTS summary saved to: {tts_summary_output_path}")
    
    # Save speaker summary
    speaker_summary_output_path = "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_summary_lse_edtalk_speaker.csv"
    speaker_summary_df.to_csv(speaker_summary_output_path, index=False)
    print(f"Speaker summary saved to: {speaker_summary_output_path}")
    
    # Save comparison
    comparison_output_path = "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_comparison_avatar_v15.csv"
    comparison_df.to_csv(comparison_output_path, index=False)
    print(f"Avatar vs V15 comparison saved to: {comparison_output_path}")

else:
    print("No results found!")

print("\nEDTalk LSE evaluation completed successfully!")
# Out:
# Starting LSE evaluation for EDTalk results...
# ======================================================================
#
# Processing RAW_v15 dataset...
# Folder: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/edtalk-exp/EDTalk/results/test_raw/v15/RAW
# Calculating LSE scores for RAW_v15 videos in: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/edtalk-exp/EDTalk/results/test_raw/v15/RAW
# Created temp folder with 60 files
# Running command: python calculate_scores_LRS.py --data_root temp_512_RAW_v15 --tmp_dir tmp_dir_RAW_v15
# STDOUT: Average Confidence: 2.967564654350281
# Average Minimum Distance: 9.928580323855082
#
# STDERR:
#   0%|          | 0/60 [00:00<?, ?it/s]
# Avg Confidence: 0.97, Avg Minimum Dist: 11.472:   0%|          | 0/60 [00:03<?, ?it/s]
# Avg Confidence: 0.97, Avg Minimum Dist: 11.472:   0%|          | 0/60 [00:03<?, ?it/s]
# Avg Confidence: 0.97, Avg Minimum Dist: 11.472:   2%|▏         | 1/60 [00:03<03:28,  3.53s/it]
# Avg Confidence: 2.712, Avg Minimum Dist: 9.642:   2%|▏         | 1/60 [00:06<03:28,  3.53s/it]
# Avg Confidence: 2.712, Avg Minimum Dist: 9.642:   2%|▏         | 1/60 [00:06<03:28,  3.53s/it]
# Avg Confidence: 2.712, Avg Minimum Dist: 9.642:   3%|▎         | 2/60 [00:06<02:50,  2.94s/it]
# Avg Confidence: 2.13, Avg Minimum Dist: 10.79:   3%|▎         | 2/60 [00:07<02:50,  2.94s/it]
# Avg Confidence: 2.13, Avg Minimum Dist: 10.79:   3%|▎         | 2/60 [00:07<02:50,  2.94s/it]
# Avg Confidence: 2.13, Avg Minimum Dist: 10.79:   5%|▌         | 3/60 [00:07<02:12,  2.33s/it]
# Avg Confidence: 2.456, Avg Minimum Dist: 10.672:   5%|▌         | 3/60 [00:09<02:12,  2.33s/it]
# Avg Confidence: 2.456, Avg Minimum Dist: 10.672:   5%|▌         | 3/60 [00:09<02:12,  2.33s/it]
# Avg Confidence: 2.456, Avg Minimum Dist: 10.672:   7%|▋         | 4/60 [00:09<02:03,  2.21s/it]
# Avg Confidence: 2.549, Avg Minimum Dist: 10.709:   7%|▋         | 4/60 [00:12<02:03,  2.21s/it]
# Avg Confidence: 2.549, Avg Minimum Dist: 10.709:   7%|▋         | 4/60 [00:12<02:03,  2.21s/it]
# Avg Confidence: 2.549, Avg Minimum Dist: 10.709:   8%|▊         | 5/60 [00:12<02:13,  2.42s/it]
# Avg Confidence: 2.715, Avg Minimum Dist: 10.62:   8%|▊         | 5/60 [00:15<02:13,  2.42s/it]
# Avg Confidence: 2.715, Avg Minimum Dist: 10.62:   8%|▊         | 5/60 [00:15<02:13,  2.42s/it]
# Avg Confidence: 2.715, Avg Minimum Dist: 10.62:  10%|█         | 6/60 [00:15<02:17,  2.55s/it]
# Avg Confidence: 2.835, Avg Minimum Dist: 10.532:  10%|█         | 6/60 [00:17<02:17,  2.55s/it]
# Avg Confidence: 2.835, Avg Minimum Dist: 10.532:  10%|█         | 6/60 [00:17<02:17,  2.55s/it]
# Avg Confidence: 2.835, Avg Minimum Dist: 10.532:  12%|█▏        | 7/60 [00:17<02:18,  2.61s/it]
# Avg Confidence: 2.647, Avg Minimum Dist: 10.477:  12%|█▏        | 7/60 [00:19<02:18,  2.61s/it]
# Avg Confidence: 2.647, Avg Minimum Dist: 10.477:  12%|█▏        | 7/60 [00:19<02:18,  2.61s/it]
# Avg Confidence: 2.647, Avg Minimum Dist: 10.477:  13%|█▎        | 8/60 [00:19<01:54,  2.20s/it]
# Avg Confidence: 2.517, Avg Minimum Dist: 10.561:  13%|█▎        | 8/60 [00:20<01:54,  2.20s/it]
# Avg Confidence: 2.517, Avg Minimum Dist: 10.561:  13%|█▎        | 8/60 [00:20<01:54,  2.20s/it]
# Avg Confidence: 2.517, Avg Minimum Dist: 10.561:  15%|█▌        | 9/60 [00:20<01:40,  1.98s/it]
# Avg Confidence: 2.782, Avg Minimum Dist: 10.303:  15%|█▌        | 9/60 [00:22<01:40,  1.98s/it]
# Avg Confidence: 2.782, Avg Minimum Dist: 10.303:  15%|█▌        | 9/60 [00:22<01:40,  1.98s/it]
# Avg Confidence: 2.782, Avg Minimum Dist: 10.303:  17%|█▋        | 10/60 [00:22<01:38,  1.97s/it]
# Avg Confidence: 2.727, Avg Minimum Dist: 10.338:  17%|█▋        | 10/60 [00:24<01:38,  1.97s/it]
# Avg Confidence: 2.727, Avg Minimum Dist: 10.338:  17%|█▋        | 10/60 [00:24<01:38,  1.97s/it]
# Avg Confidence: 2.727, Avg Minimum Dist: 10.338:  18%|█▊        | 11/60 [00:24<01:33,  1.90s/it]
# Avg Confidence: 2.922, Avg Minimum Dist: 10.122:  18%|█▊        | 11/60 [00:26<01:33,  1.90s/it]
# Avg Confidence: 2.922, Avg Minimum Dist: 10.122:  18%|█▊        | 11/60 [00:26<01:33,  1.90s/it]
# Avg Confidence: 2.922, Avg Minimum Dist: 10.122:  20%|██        | 12/60 [00:26<01:32,  1.93s/it]
# Avg Confidence: 2.9, Avg Minimum Dist: 10.083:  20%|██        | 12/60 [00:28<01:32,  1.93s/it]
# Avg Confidence: 2.9, Avg Minimum Dist: 10.083:  20%|██        | 12/60 [00:28<01:32,  1.93s/it]
# Avg Confidence: 2.9, Avg Minimum Dist: 10.083:  22%|██▏       | 13/60 [00:28<01:32,  1.98s/it]
# Avg Confidence: 3.069, Avg Minimum Dist: 9.927:  22%|██▏       | 13/60 [00:31<01:32,  1.98s/it]
# Avg Confidence: 3.069, Avg Minimum Dist: 9.927:  22%|██▏       | 13/60 [00:31<01:32,  1.98s/it]
# Avg Confidence: 3.069, Avg Minimum Dist: 9.927:  23%|██▎       | 14/60 [00:31<01:46,  2.32s/it]
# Avg Confidence: 3.017, Avg Minimum Dist: 10.033:  23%|██▎       | 14/60 [00:33<01:46,  2.32s/it]
# Avg Confidence: 3.017, Avg Minimum Dist: 10.033:  23%|██▎       | 14/60 [00:33<01:46,  2.32s/it]
# Avg Confidence: 3.017, Avg Minimum Dist: 10.033:  25%|██▌       | 15/60 [00:33<01:36,  2.14s/it]
# Avg Confidence: 2.982, Avg Minimum Dist: 10.078:  25%|██▌       | 15/60 [00:35<01:36,  2.14s/it]
# Avg Confidence: 2.982, Avg Minimum Dist: 10.078:  25%|██▌       | 15/60 [00:35<01:36,  2.14s/it]
# Avg Confidence: 2.982, Avg Minimum Dist: 10.078:  27%|██▋       | 16/60 [00:35<01:32,  2.11s/it]
# Avg Confidence: 3.143, Avg Minimum Dist: 9.964:  27%|██▋       | 16/60 [00:37<01:32,  2.11s/it]
# Avg Confidence: 3.143, Avg Minimum Dist: 9.964:  27%|██▋       | 16/60 [00:37<01:32,  2.11s/it]
# Avg Confidence: 3.143, Avg Minimum Dist: 9.964:  28%|██▊       | 17/60 [00:37<01:31,  2.13s/it]
# Avg Confidence: 3.078, Avg Minimum Dist: 9.993:  28%|██▊       | 17/60 [00:39<01:31,  2.13s/it]
# Avg Confidence: 3.078, Avg Minimum Dist: 9.993:  28%|██▊       | 17/60 [00:39<01:31,  2.13s/it]
# Avg Confidence: 3.078, Avg Minimum Dist: 9.993:  30%|███       | 18/60 [00:39<01:31,  2.18s/it]
# Avg Confidence: 3.201, Avg Minimum Dist: 9.894:  30%|███       | 18/60 [00:42<01:31,  2.18s/it]
# Avg Confidence: 3.201, Avg Minimum Dist: 9.894:  30%|███       | 18/60 [00:42<01:31,  2.18s/it]
# Avg Confidence: 3.201, Avg Minimum Dist: 9.894:  32%|███▏      | 19/60 [00:42<01:33,  2.29s/it]
# Avg Confidence: 3.138, Avg Minimum Dist: 9.981:  32%|███▏      | 19/60 [00:44<01:33,  2.29s/it]
# Avg Confidence: 3.138, Avg Minimum Dist: 9.981:  32%|███▏      | 19/60 [00:44<01:33,  2.29s/it]
# Avg Confidence: 3.138, Avg Minimum Dist: 9.981:  33%|███▎      | 20/60 [00:44<01:30,  2.27s/it]
# Avg Confidence: 3.243, Avg Minimum Dist: 9.97:  33%|███▎      | 20/60 [00:47<01:30,  2.27s/it]
# Avg Confidence: 3.243, Avg Minimum Dist: 9.97:  33%|███▎      | 20/60 [00:47<01:30,  2.27s/it]
# Avg Confidence: 3.243, Avg Minimum Dist: 9.97:  35%|███▌      | 21/60 [00:47<01:38,  2.53s/it]
# Avg Confidence: 3.234, Avg Minimum Dist: 9.929:  35%|███▌      | 21/60 [00:49<01:38,  2.53s/it]
# Avg Confidence: 3.234, Avg Minimum Dist: 9.929:  35%|███▌      | 21/60 [00:49<01:38,  2.53s/it]
# Avg Confidence: 3.234, Avg Minimum Dist: 9.929:  37%|███▋      | 22/60 [00:49<01:26,  2.28s/it]
# Avg Confidence: 3.197, Avg Minimum Dist: 9.995:  37%|███▋      | 22/60 [00:51<01:26,  2.28s/it]
# Avg Confidence: 3.197, Avg Minimum Dist: 9.995:  37%|███▋      | 22/60 [00:51<01:26,  2.28s/it]
# Avg Confidence: 3.197, Avg Minimum Dist: 9.995:  38%|███▊      | 23/60 [00:51<01:18,  2.13s/it]
# Avg Confidence: 3.234, Avg Minimum Dist: 10.023:  38%|███▊      | 23/60 [00:52<01:18,  2.13s/it]
# Avg Confidence: 3.234, Avg Minimum Dist: 10.023:  38%|███▊      | 23/60 [00:52<01:18,  2.13s/it]
# Avg Confidence: 3.234, Avg Minimum Dist: 10.023:  40%|████      | 24/60 [00:52<01:09,  1.92s/it]
# Avg Confidence: 3.128, Avg Minimum Dist: 10.101:  40%|████      | 24/60 [00:54<01:09,  1.92s/it]
# Avg Confidence: 3.128, Avg Minimum Dist: 10.101:  40%|████      | 24/60 [00:54<01:09,  1.92s/it]
# Avg Confidence: 3.128, Avg Minimum Dist: 10.101:  42%|████▏     | 25/60 [00:54<01:01,  1.77s/it]
# Avg Confidence: 3.072, Avg Minimum Dist: 10.031:  42%|████▏     | 25/60 [00:55<01:01,  1.77s/it]
# Avg Confidence: 3.072, Avg Minimum Dist: 10.031:  42%|████▏     | 25/60 [00:55<01:01,  1.77s/it]
# Avg Confidence: 3.072, Avg Minimum Dist: 10.031:  43%|████▎     | 26/60 [00:55<00:53,  1.59s/it]
# Avg Confidence: 3.105, Avg Minimum Dist: 9.992:  43%|████▎     | 26/60 [00:57<00:53,  1.59s/it]
# Avg Confidence: 3.105, Avg Minimum Dist: 9.992:  43%|████▎     | 26/60 [00:57<00:53,  1.59s/it]
# Avg Confidence: 3.105, Avg Minimum Dist: 9.992:  45%|████▌     | 27/60 [00:57<00:56,  1.72s/it]
# Avg Confidence: 3.036, Avg Minimum Dist: 10.044:  45%|████▌     | 27/60 [00:59<00:56,  1.72s/it]
# Avg Confidence: 3.036, Avg Minimum Dist: 10.044:  45%|████▌     | 27/60 [00:59<00:56,  1.72s/it]
# Avg Confidence: 3.036, Avg Minimum Dist: 10.044:  47%|████▋     | 28/60 [00:59<01:00,  1.89s/it]
# Avg Confidence: 3.014, Avg Minimum Dist: 10.055:  47%|████▋     | 28/60 [01:02<01:00,  1.89s/it]
# Avg Confidence: 3.014, Avg Minimum Dist: 10.055:  47%|████▋     | 28/60 [01:02<01:00,  1.89s/it]
# Avg Confidence: 3.014, Avg Minimum Dist: 10.055:  48%|████▊     | 29/60 [01:02<01:03,  2.04s/it]
# Avg Confidence: 3.01, Avg Minimum Dist: 10.097:  48%|████▊     | 29/60 [01:03<01:03,  2.04s/it]
# Avg Confidence: 3.01, Avg Minimum Dist: 10.097:  48%|████▊     | 29/60 [01:03<01:03,  2.04s/it]
# Avg Confidence: 3.01, Avg Minimum Dist: 10.097:  50%|█████     | 30/60 [01:03<00:57,  1.91s/it]
# Avg Confidence: 2.959, Avg Minimum Dist: 10.114:  50%|█████     | 30/60 [01:05<00:57,  1.91s/it]
# Avg Confidence: 2.959, Avg Minimum Dist: 10.114:  50%|█████     | 30/60 [01:05<00:57,  1.91s/it]
# Avg Confidence: 2.959, Avg Minimum Dist: 10.114:  52%|█████▏    | 31/60 [01:05<00:55,  1.90s/it]
# Avg Confidence: 2.984, Avg Minimum Dist: 10.095:  52%|█████▏    | 31/60 [01:07<00:55,  1.90s/it]
# Avg Confidence: 2.984, Avg Minimum Dist: 10.095:  52%|█████▏    | 31/60 [01:07<00:55,  1.90s/it]
# Avg Confidence: 2.984, Avg Minimum Dist: 10.095:  53%|█████▎    | 32/60 [01:07<00:53,  1.89s/it]
# Avg Confidence: 2.992, Avg Minimum Dist: 10.09:  53%|█████▎    | 32/60 [01:08<00:53,  1.89s/it]
# Avg Confidence: 2.992, Avg Minimum Dist: 10.09:  53%|█████▎    | 32/60 [01:08<00:53,  1.89s/it]
# Avg Confidence: 2.992, Avg Minimum Dist: 10.09:  55%|█████▌    | 33/60 [01:08<00:48,  1.80s/it]
# Avg Confidence: 2.995, Avg Minimum Dist: 10.065:  55%|█████▌    | 33/60 [01:11<00:48,  1.80s/it]
# Avg Confidence: 2.995, Avg Minimum Dist: 10.065:  55%|█████▌    | 33/60 [01:11<00:48,  1.80s/it]
# Avg Confidence: 2.995, Avg Minimum Dist: 10.065:  57%|█████▋    | 34/60 [01:11<00:52,  2.02s/it]
# Avg Confidence: 2.989, Avg Minimum Dist: 10.089:  57%|█████▋    | 34/60 [01:12<00:52,  2.02s/it]
# Avg Confidence: 2.989, Avg Minimum Dist: 10.089:  57%|█████▋    | 34/60 [01:12<00:52,  2.02s/it]
# Avg Confidence: 2.989, Avg Minimum Dist: 10.089:  58%|█████▊    | 35/60 [01:12<00:45,  1.83s/it]
# Avg Confidence: 2.966, Avg Minimum Dist: 10.111:  58%|█████▊    | 35/60 [01:15<00:45,  1.83s/it]
# Avg Confidence: 2.966, Avg Minimum Dist: 10.111:  58%|█████▊    | 35/60 [01:15<00:45,  1.83s/it]
# Avg Confidence: 2.966, Avg Minimum Dist: 10.111:  60%|██████    | 36/60 [01:15<00:49,  2.05s/it]
# Avg Confidence: 3.016, Avg Minimum Dist: 10.058:  60%|██████    | 36/60 [01:17<00:49,  2.05s/it]
# Avg Confidence: 3.016, Avg Minimum Dist: 10.058:  60%|██████    | 36/60 [01:17<00:49,  2.05s/it]
# Avg Confidence: 3.016, Avg Minimum Dist: 10.058:  62%|██████▏   | 37/60 [01:17<00:45,  1.98s/it]
# Avg Confidence: 2.982, Avg Minimum Dist: 10.132:  62%|██████▏   | 37/60 [01:18<00:45,  1.98s/it]
# Avg Confidence: 2.982, Avg Minimum Dist: 10.132:  62%|██████▏   | 37/60 [01:18<00:45,  1.98s/it]
# Avg Confidence: 2.982, Avg Minimum Dist: 10.132:  63%|██████▎   | 38/60 [01:18<00:41,  1.88s/it]
# Avg Confidence: 2.98, Avg Minimum Dist: 10.124:  63%|██████▎   | 38/60 [01:20<00:41,  1.88s/it]
# Avg Confidence: 2.98, Avg Minimum Dist: 10.124:  63%|██████▎   | 38/60 [01:20<00:41,  1.88s/it]
# Avg Confidence: 2.98, Avg Minimum Dist: 10.124:  65%|██████▌   | 39/60 [01:20<00:37,  1.76s/it]
# Avg Confidence: 2.949, Avg Minimum Dist: 10.027:  65%|██████▌   | 39/60 [01:22<00:37,  1.76s/it]
# Avg Confidence: 2.949, Avg Minimum Dist: 10.027:  65%|██████▌   | 39/60 [01:22<00:37,  1.76s/it]
# Avg Confidence: 2.949, Avg Minimum Dist: 10.027:  67%|██████▋   | 40/60 [01:22<00:37,  1.85s/it]
# Avg Confidence: 2.97, Avg Minimum Dist: 10.012:  67%|██████▋   | 40/60 [01:24<00:37,  1.85s/it]
# Avg Confidence: 2.97, Avg Minimum Dist: 10.012:  67%|██████▋   | 40/60 [01:24<00:37,  1.85s/it]
# Avg Confidence: 2.97, Avg Minimum Dist: 10.012:  68%|██████▊   | 41/60 [01:24<00:34,  1.81s/it]
# Avg Confidence: 2.971, Avg Minimum Dist: 10.012:  68%|██████▊   | 41/60 [01:26<00:34,  1.81s/it]
# Avg Confidence: 2.971, Avg Minimum Dist: 10.012:  68%|██████▊   | 41/60 [01:26<00:34,  1.81s/it]
# Avg Confidence: 2.971, Avg Minimum Dist: 10.012:  70%|███████   | 42/60 [01:26<00:33,  1.84s/it]
# Avg Confidence: 2.992, Avg Minimum Dist: 9.97:  70%|███████   | 42/60 [01:28<00:33,  1.84s/it]
# Avg Confidence: 2.992, Avg Minimum Dist: 9.97:  70%|███████   | 42/60 [01:28<00:33,  1.84s/it]
# Avg Confidence: 2.992, Avg Minimum Dist: 9.97:  72%|███████▏  | 43/60 [01:28<00:32,  1.92s/it]
# Avg Confidence: 2.966, Avg Minimum Dist: 10.018:  72%|███████▏  | 43/60 [01:29<00:32,  1.92s/it]
# Avg Confidence: 2.966, Avg Minimum Dist: 10.018:  72%|███████▏  | 43/60 [01:29<00:32,  1.92s/it]
# Avg Confidence: 2.966, Avg Minimum Dist: 10.018:  73%|███████▎  | 44/60 [01:29<00:28,  1.75s/it]
# Avg Confidence: 2.959, Avg Minimum Dist: 10.019:  73%|███████▎  | 44/60 [01:31<00:28,  1.75s/it]
# Avg Confidence: 2.959, Avg Minimum Dist: 10.019:  73%|███████▎  | 44/60 [01:31<00:28,  1.75s/it]
# Avg Confidence: 2.959, Avg Minimum Dist: 10.019:  75%|███████▌  | 45/60 [01:31<00:26,  1.78s/it]
# Avg Confidence: 2.98, Avg Minimum Dist: 9.997:  75%|███████▌  | 45/60 [01:33<00:26,  1.78s/it]
# Avg Confidence: 2.98, Avg Minimum Dist: 9.997:  75%|███████▌  | 45/60 [01:33<00:26,  1.78s/it]
# Avg Confidence: 2.98, Avg Minimum Dist: 9.997:  77%|███████▋  | 46/60 [01:33<00:26,  1.88s/it]
# Avg Confidence: 2.963, Avg Minimum Dist: 9.987:  77%|███████▋  | 46/60 [01:35<00:26,  1.88s/it]
# Avg Confidence: 2.963, Avg Minimum Dist: 9.987:  77%|███████▋  | 46/60 [01:35<00:26,  1.88s/it]
# Avg Confidence: 2.963, Avg Minimum Dist: 9.987:  78%|███████▊  | 47/60 [01:35<00:25,  2.00s/it]
# Avg Confidence: 2.961, Avg Minimum Dist: 9.961:  78%|███████▊  | 47/60 [01:38<00:25,  2.00s/it]
# Avg Confidence: 2.961, Avg Minimum Dist: 9.961:  78%|███████▊  | 47/60 [01:38<00:25,  2.00s/it]
# Avg Confidence: 2.961, Avg Minimum Dist: 9.961:  80%|████████  | 48/60 [01:38<00:27,  2.29s/it]
# Avg Confidence: 2.932, Avg Minimum Dist: 10.005:  80%|████████  | 48/60 [01:40<00:27,  2.29s/it]
# Avg Confidence: 2.932, Avg Minimum Dist: 10.005:  80%|████████  | 48/60 [01:40<00:27,  2.29s/it]
# Avg Confidence: 2.932, Avg Minimum Dist: 10.005:  82%|████████▏ | 49/60 [01:40<00:24,  2.25s/it]
# Avg Confidence: 2.996, Avg Minimum Dist: 9.952:  82%|████████▏ | 49/60 [01:42<00:24,  2.25s/it]
# Avg Confidence: 2.996, Avg Minimum Dist: 9.952:  82%|████████▏ | 49/60 [01:42<00:24,  2.25s/it]
# Avg Confidence: 2.996, Avg Minimum Dist: 9.952:  83%|████████▎ | 50/60 [01:42<00:21,  2.19s/it]
# Avg Confidence: 3.041, Avg Minimum Dist: 9.925:  83%|████████▎ | 50/60 [01:44<00:21,  2.19s/it]
# Avg Confidence: 3.041, Avg Minimum Dist: 9.925:  83%|████████▎ | 50/60 [01:44<00:21,  2.19s/it]
# Avg Confidence: 3.041, Avg Minimum Dist: 9.925:  85%|████████▌ | 51/60 [01:44<00:18,  2.05s/it]
# Avg Confidence: 3.035, Avg Minimum Dist: 9.94:  85%|████████▌ | 51/60 [01:46<00:18,  2.05s/it]
# Avg Confidence: 3.035, Avg Minimum Dist: 9.94:  85%|████████▌ | 51/60 [01:46<00:18,  2.05s/it]
# Avg Confidence: 3.035, Avg Minimum Dist: 9.94:  87%|████████▋ | 52/60 [01:46<00:14,  1.86s/it]
# Avg Confidence: 3.032, Avg Minimum Dist: 9.937:  87%|████████▋ | 52/60 [01:48<00:14,  1.86s/it]
# Avg Confidence: 3.032, Avg Minimum Dist: 9.937:  87%|████████▋ | 52/60 [01:48<00:14,  1.86s/it]
# Avg Confidence: 3.032, Avg Minimum Dist: 9.937:  88%|████████▊ | 53/60 [01:48<00:14,  2.08s/it]
# Avg Confidence: 3.054, Avg Minimum Dist: 9.926:  88%|████████▊ | 53/60 [01:50<00:14,  2.08s/it]
# Avg Confidence: 3.054, Avg Minimum Dist: 9.926:  88%|████████▊ | 53/60 [01:50<00:14,  2.08s/it]
# Avg Confidence: 3.054, Avg Minimum Dist: 9.926:  90%|█████████ | 54/60 [01:50<00:11,  1.99s/it]
# Avg Confidence: 3.029, Avg Minimum Dist: 9.945:  90%|█████████ | 54/60 [01:52<00:11,  1.99s/it]
# Avg Confidence: 3.029, Avg Minimum Dist: 9.945:  90%|█████████ | 54/60 [01:52<00:11,  1.99s/it]
# Avg Confidence: 3.029, Avg Minimum Dist: 9.945:  92%|█████████▏| 55/60 [01:52<00:09,  1.89s/it]
# Avg Confidence: 3.009, Avg Minimum Dist: 9.94:  92%|█████████▏| 55/60 [01:54<00:09,  1.89s/it]
# Avg Confidence: 3.009, Avg Minimum Dist: 9.94:  92%|█████████▏| 55/60 [01:54<00:09,  1.89s/it]
# Avg Confidence: 3.009, Avg Minimum Dist: 9.94:  93%|█████████▎| 56/60 [01:54<00:07,  1.97s/it]
# Avg Confidence: 3.016, Avg Minimum Dist: 9.938:  93%|█████████▎| 56/60 [01:55<00:07,  1.97s/it]
# Avg Confidence: 3.016, Avg Minimum Dist: 9.938:  93%|█████████▎| 56/60 [01:55<00:07,  1.97s/it]
# Avg Confidence: 3.016, Avg Minimum Dist: 9.938:  95%|█████████▌| 57/60 [01:55<00:05,  1.85s/it]
# Avg Confidence: 3.023, Avg Minimum Dist: 9.922:  95%|█████████▌| 57/60 [01:57<00:05,  1.85s/it]
# Avg Confidence: 3.023, Avg Minimum Dist: 9.922:  95%|█████████▌| 57/60 [01:57<00:05,  1.85s/it]
# Avg Confidence: 3.023, Avg Minimum Dist: 9.922:  97%|█████████▋| 58/60 [01:57<00:03,  1.88s/it]
# Avg Confidence: 2.997, Avg Minimum Dist: 9.905:  97%|█████████▋| 58/60 [02:00<00:03,  1.88s/it]
# Avg Confidence: 2.997, Avg Minimum Dist: 9.905:  97%|█████████▋| 58/60 [02:00<00:03,  1.88s/it]
# Avg Confidence: 2.997, Avg Minimum Dist: 9.905:  98%|█████████▊| 59/60 [02:00<00:02,  2.06s/it]
# Avg Confidence: 2.968, Avg Minimum Dist: 9.929:  98%|█████████▊| 59/60 [02:01<00:02,  2.06s/it]
# Avg Confidence: 2.968, Avg Minimum Dist: 9.929:  98%|█████████▊| 59/60 [02:01<00:02,  2.06s/it]
# Avg Confidence: 2.968, Avg Minimum Dist: 9.929: 100%|██████████| 60/60 [02:01<00:00,  1.89s/it]
# Avg Confidence: 2.968, Avg Minimum Dist: 9.929: 100%|██████████| 60/60 [02:01<00:00,  2.03s/it]
#
#
# RAW_v15 Results:
#   Average Confidence (LSE-C): 2.9676
#   Average Minimum Distance (LSE-D): 9.9286
#
# RAW_v15 Overall Scores:
#   LSE-C (Confidence): 2.9676
#   LSE-D (Distance): 9.9286
#   Total 512 res files processed: 60
# Sample files processed:
#   1. S005_02_BBP_NORMAL_color_25fps_6sec_CV_S005_BBP_cloned_512.mp4
#   2. S001_02_DDK_PA_color_25fps_6sec_XT_S001_PA_cloned_512.mp4
#   3. A016_02_BBP_NORMAL_color_25fps_6sec_CV_A016_BBP_cloned_512.mp4
#   4. A008_02_BBP_NORMAL_color_25fps_6sec_CV_A008_BBP_cloned_512.mp4
#   5. A017_02_BBP_NORMAL_color_25fps_6sec_CV_A017_BBP_cloned_512.mp4
#
# Processing VCTK_v15 dataset...
# Folder: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/edtalk-exp/EDTalk/results/test_vctk/v15/VCTK
# Calculating LSE scores for VCTK_v15 videos in: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/edtalk-exp/EDTalk/results/test_vctk/v15/VCTK
# Created temp folder with 60 files
# Running command: python calculate_scores_LRS.py --data_root temp_512_VCTK_v15 --tmp_dir tmp_dir_VCTK_v15
# STDOUT: Average Confidence: 3.252932866414388
# Average Minimum Distance: 9.224697748819986
#
# STDERR:
#   0%|          | 0/60 [00:00<?, ?it/s]
# Avg Confidence: 3.756, Avg Minimum Dist: 8.34:   0%|          | 0/60 [00:01<?, ?it/s]
# Avg Confidence: 3.756, Avg Minimum Dist: 8.34:   0%|          | 0/60 [00:01<?, ?it/s]
# Avg Confidence: 3.756, Avg Minimum Dist: 8.34:   2%|▏         | 1/60 [00:01<01:41,  1.72s/it]
# Avg Confidence: 4.45, Avg Minimum Dist: 7.935:   2%|▏         | 1/60 [00:02<01:41,  1.72s/it]
# Avg Confidence: 4.45, Avg Minimum Dist: 7.935:   2%|▏         | 1/60 [00:02<01:41,  1.72s/it]
# Avg Confidence: 4.45, Avg Minimum Dist: 7.935:   3%|▎         | 2/60 [00:02<01:24,  1.46s/it]
# Avg Confidence: 3.343, Avg Minimum Dist: 9.497:   3%|▎         | 2/60 [00:04<01:24,  1.46s/it]
# Avg Confidence: 3.343, Avg Minimum Dist: 9.497:   3%|▎         | 2/60 [00:04<01:24,  1.46s/it]
# Avg Confidence: 3.343, Avg Minimum Dist: 9.497:   5%|▌         | 3/60 [00:04<01:25,  1.51s/it]
# Avg Confidence: 3.079, Avg Minimum Dist: 10.06:   5%|▌         | 3/60 [00:06<01:25,  1.51s/it]
# Avg Confidence: 3.079, Avg Minimum Dist: 10.06:   5%|▌         | 3/60 [00:06<01:25,  1.51s/it]
# Avg Confidence: 3.079, Avg Minimum Dist: 10.06:   7%|▋         | 4/60 [00:06<01:35,  1.71s/it]
# Avg Confidence: 3.023, Avg Minimum Dist: 9.83:   7%|▋         | 4/60 [00:08<01:35,  1.71s/it]
# Avg Confidence: 3.023, Avg Minimum Dist: 9.83:   7%|▋         | 4/60 [00:08<01:35,  1.71s/it]
# Avg Confidence: 3.023, Avg Minimum Dist: 9.83:   8%|▊         | 5/60 [00:08<01:40,  1.84s/it]
# Avg Confidence: 3.003, Avg Minimum Dist: 9.948:   8%|▊         | 5/60 [00:10<01:40,  1.84s/it]
# Avg Confidence: 3.003, Avg Minimum Dist: 9.948:   8%|▊         | 5/60 [00:10<01:40,  1.84s/it]
# Avg Confidence: 3.003, Avg Minimum Dist: 9.948:  10%|█         | 6/60 [00:10<01:44,  1.94s/it]
# Avg Confidence: 2.88, Avg Minimum Dist: 9.948:  10%|█         | 6/60 [00:13<01:44,  1.94s/it]
# Avg Confidence: 2.88, Avg Minimum Dist: 9.948:  10%|█         | 6/60 [00:13<01:44,  1.94s/it]
# Avg Confidence: 2.88, Avg Minimum Dist: 9.948:  12%|█▏        | 7/60 [00:13<01:48,  2.04s/it]
# Avg Confidence: 3.177, Avg Minimum Dist: 9.703:  12%|█▏        | 7/60 [00:14<01:48,  2.04s/it]
# Avg Confidence: 3.177, Avg Minimum Dist: 9.703:  12%|█▏        | 7/60 [00:14<01:48,  2.04s/it]
# Avg Confidence: 3.177, Avg Minimum Dist: 9.703:  13%|█▎        | 8/60 [00:14<01:33,  1.80s/it]
# Avg Confidence: 3.123, Avg Minimum Dist: 9.597:  13%|█▎        | 8/60 [00:16<01:33,  1.80s/it]
# Avg Confidence: 3.123, Avg Minimum Dist: 9.597:  13%|█▎        | 8/60 [00:16<01:33,  1.80s/it]
# Avg Confidence: 3.123, Avg Minimum Dist: 9.597:  15%|█▌        | 9/60 [00:16<01:36,  1.89s/it]
# Avg Confidence: 3.222, Avg Minimum Dist: 9.443:  15%|█▌        | 9/60 [00:17<01:36,  1.89s/it]
# Avg Confidence: 3.222, Avg Minimum Dist: 9.443:  15%|█▌        | 9/60 [00:17<01:36,  1.89s/it]
# Avg Confidence: 3.222, Avg Minimum Dist: 9.443:  17%|█▋        | 10/60 [00:17<01:27,  1.74s/it]
# Avg Confidence: 3.209, Avg Minimum Dist: 9.329:  17%|█▋        | 10/60 [00:19<01:27,  1.74s/it]
# Avg Confidence: 3.209, Avg Minimum Dist: 9.329:  17%|█▋        | 10/60 [00:19<01:27,  1.74s/it]
# Avg Confidence: 3.209, Avg Minimum Dist: 9.329:  18%|█▊        | 11/60 [00:19<01:26,  1.77s/it]
# Avg Confidence: 3.424, Avg Minimum Dist: 9.116:  18%|█▊        | 11/60 [00:21<01:26,  1.77s/it]
# Avg Confidence: 3.424, Avg Minimum Dist: 9.116:  18%|█▊        | 11/60 [00:21<01:26,  1.77s/it]
# Avg Confidence: 3.424, Avg Minimum Dist: 9.116:  20%|██        | 12/60 [00:21<01:24,  1.76s/it]
# Avg Confidence: 3.28, Avg Minimum Dist: 9.309:  20%|██        | 12/60 [00:23<01:24,  1.76s/it]
# Avg Confidence: 3.28, Avg Minimum Dist: 9.309:  20%|██        | 12/60 [00:23<01:24,  1.76s/it]
# Avg Confidence: 3.28, Avg Minimum Dist: 9.309:  22%|██▏       | 13/60 [00:23<01:21,  1.74s/it]
# Avg Confidence: 3.327, Avg Minimum Dist: 9.233:  22%|██▏       | 13/60 [00:24<01:21,  1.74s/it]
# Avg Confidence: 3.327, Avg Minimum Dist: 9.233:  22%|██▏       | 13/60 [00:24<01:21,  1.74s/it]
# Avg Confidence: 3.327, Avg Minimum Dist: 9.233:  23%|██▎       | 14/60 [00:24<01:17,  1.68s/it]
# Avg Confidence: 3.213, Avg Minimum Dist: 9.314:  23%|██▎       | 14/60 [00:26<01:17,  1.68s/it]
# Avg Confidence: 3.213, Avg Minimum Dist: 9.314:  23%|██▎       | 14/60 [00:26<01:17,  1.68s/it]
# Avg Confidence: 3.213, Avg Minimum Dist: 9.314:  25%|██▌       | 15/60 [00:26<01:18,  1.75s/it]
# Avg Confidence: 3.201, Avg Minimum Dist: 9.315:  25%|██▌       | 15/60 [00:28<01:18,  1.75s/it]
# Avg Confidence: 3.201, Avg Minimum Dist: 9.315:  25%|██▌       | 15/60 [00:28<01:18,  1.75s/it]
# Avg Confidence: 3.201, Avg Minimum Dist: 9.315:  27%|██▋       | 16/60 [00:28<01:21,  1.86s/it]
# Avg Confidence: 3.135, Avg Minimum Dist: 9.443:  27%|██▋       | 16/60 [00:30<01:21,  1.86s/it]
# Avg Confidence: 3.135, Avg Minimum Dist: 9.443:  27%|██▋       | 16/60 [00:30<01:21,  1.86s/it]
# Avg Confidence: 3.135, Avg Minimum Dist: 9.443:  28%|██▊       | 17/60 [00:30<01:14,  1.72s/it]
# Avg Confidence: 2.992, Avg Minimum Dist: 9.682:  28%|██▊       | 17/60 [00:31<01:14,  1.72s/it]
# Avg Confidence: 2.992, Avg Minimum Dist: 9.682:  28%|██▊       | 17/60 [00:31<01:14,  1.72s/it]
# Avg Confidence: 2.992, Avg Minimum Dist: 9.682:  30%|███       | 18/60 [00:31<01:08,  1.63s/it]
# Avg Confidence: 2.964, Avg Minimum Dist: 9.542:  30%|███       | 18/60 [00:33<01:08,  1.63s/it]
# Avg Confidence: 2.964, Avg Minimum Dist: 9.542:  30%|███       | 18/60 [00:33<01:08,  1.63s/it]
# Avg Confidence: 2.964, Avg Minimum Dist: 9.542:  32%|███▏      | 19/60 [00:33<01:16,  1.87s/it]
# Avg Confidence: 3.075, Avg Minimum Dist: 9.453:  32%|███▏      | 19/60 [00:35<01:16,  1.87s/it]
# Avg Confidence: 3.075, Avg Minimum Dist: 9.453:  32%|███▏      | 19/60 [00:35<01:16,  1.87s/it]
# Avg Confidence: 3.075, Avg Minimum Dist: 9.453:  33%|███▎      | 20/60 [00:35<01:12,  1.81s/it]
# Avg Confidence: 3.108, Avg Minimum Dist: 9.405:  33%|███▎      | 20/60 [00:37<01:12,  1.81s/it]
# Avg Confidence: 3.108, Avg Minimum Dist: 9.405:  33%|███▎      | 20/60 [00:37<01:12,  1.81s/it]
# Avg Confidence: 3.108, Avg Minimum Dist: 9.405:  35%|███▌      | 21/60 [00:37<01:07,  1.73s/it]
# Avg Confidence: 3.111, Avg Minimum Dist: 9.314:  35%|███▌      | 21/60 [00:39<01:07,  1.73s/it]
# Avg Confidence: 3.111, Avg Minimum Dist: 9.314:  35%|███▌      | 21/60 [00:39<01:07,  1.73s/it]
# Avg Confidence: 3.111, Avg Minimum Dist: 9.314:  37%|███▋      | 22/60 [00:39<01:14,  1.97s/it]
# Avg Confidence: 3.097, Avg Minimum Dist: 9.355:  37%|███▋      | 22/60 [00:40<01:14,  1.97s/it]
# Avg Confidence: 3.097, Avg Minimum Dist: 9.355:  37%|███▋      | 22/60 [00:40<01:14,  1.97s/it]
# Avg Confidence: 3.097, Avg Minimum Dist: 9.355:  38%|███▊      | 23/60 [00:40<01:05,  1.78s/it]
# Avg Confidence: 3.064, Avg Minimum Dist: 9.429:  38%|███▊      | 23/60 [00:42<01:05,  1.78s/it]
# Avg Confidence: 3.064, Avg Minimum Dist: 9.429:  38%|███▊      | 23/60 [00:42<01:05,  1.78s/it]
# Avg Confidence: 3.064, Avg Minimum Dist: 9.429:  40%|████      | 24/60 [00:42<01:01,  1.72s/it]
# Avg Confidence: 3.028, Avg Minimum Dist: 9.392:  40%|████      | 24/60 [00:44<01:01,  1.72s/it]
# Avg Confidence: 3.028, Avg Minimum Dist: 9.392:  40%|████      | 24/60 [00:44<01:01,  1.72s/it]
# Avg Confidence: 3.028, Avg Minimum Dist: 9.392:  42%|████▏     | 25/60 [00:44<01:02,  1.80s/it]
# Avg Confidence: 3.008, Avg Minimum Dist: 9.416:  42%|████▏     | 25/60 [00:46<01:02,  1.80s/it]
# Avg Confidence: 3.008, Avg Minimum Dist: 9.416:  42%|████▏     | 25/60 [00:46<01:02,  1.80s/it]
# Avg Confidence: 3.008, Avg Minimum Dist: 9.416:  43%|████▎     | 26/60 [00:46<01:02,  1.83s/it]
# Avg Confidence: 3.032, Avg Minimum Dist: 9.398:  43%|████▎     | 26/60 [00:48<01:02,  1.83s/it]
# Avg Confidence: 3.032, Avg Minimum Dist: 9.398:  43%|████▎     | 26/60 [00:48<01:02,  1.83s/it]
# Avg Confidence: 3.032, Avg Minimum Dist: 9.398:  45%|████▌     | 27/60 [00:48<01:02,  1.88s/it]
# Avg Confidence: 3.058, Avg Minimum Dist: 9.414:  45%|████▌     | 27/60 [00:50<01:02,  1.88s/it]
# Avg Confidence: 3.058, Avg Minimum Dist: 9.414:  45%|████▌     | 27/60 [00:50<01:02,  1.88s/it]
# Avg Confidence: 3.058, Avg Minimum Dist: 9.414:  47%|████▋     | 28/60 [00:50<00:59,  1.85s/it]
# Avg Confidence: 3.117, Avg Minimum Dist: 9.357:  47%|████▋     | 28/60 [00:51<00:59,  1.85s/it]
# Avg Confidence: 3.117, Avg Minimum Dist: 9.357:  47%|████▋     | 28/60 [00:51<00:59,  1.85s/it]
# Avg Confidence: 3.117, Avg Minimum Dist: 9.357:  48%|████▊     | 29/60 [00:51<00:53,  1.73s/it]
# Avg Confidence: 3.187, Avg Minimum Dist: 9.29:  48%|████▊     | 29/60 [00:53<00:53,  1.73s/it]
# Avg Confidence: 3.187, Avg Minimum Dist: 9.29:  48%|████▊     | 29/60 [00:53<00:53,  1.73s/it]
# Avg Confidence: 3.187, Avg Minimum Dist: 9.29:  50%|█████     | 30/60 [00:53<00:51,  1.73s/it]
# Avg Confidence: 3.178, Avg Minimum Dist: 9.263:  50%|█████     | 30/60 [00:56<00:51,  1.73s/it]
# Avg Confidence: 3.178, Avg Minimum Dist: 9.263:  50%|█████     | 30/60 [00:56<00:51,  1.73s/it]
# Avg Confidence: 3.178, Avg Minimum Dist: 9.263:  52%|█████▏    | 31/60 [00:56<01:02,  2.15s/it]
# Avg Confidence: 3.241, Avg Minimum Dist: 9.199:  52%|█████▏    | 31/60 [00:58<01:02,  2.15s/it]
# Avg Confidence: 3.241, Avg Minimum Dist: 9.199:  52%|█████▏    | 31/60 [00:58<01:02,  2.15s/it]
# Avg Confidence: 3.241, Avg Minimum Dist: 9.199:  53%|█████▎    | 32/60 [00:58<00:58,  2.08s/it]
# Avg Confidence: 3.276, Avg Minimum Dist: 9.173:  53%|█████▎    | 32/60 [01:00<00:58,  2.08s/it]
# Avg Confidence: 3.276, Avg Minimum Dist: 9.173:  53%|█████▎    | 32/60 [01:00<00:58,  2.08s/it]
# Avg Confidence: 3.276, Avg Minimum Dist: 9.173:  55%|█████▌    | 33/60 [01:00<00:56,  2.10s/it]
# Avg Confidence: 3.286, Avg Minimum Dist: 9.191:  55%|█████▌    | 33/60 [01:01<00:56,  2.10s/it]
# Avg Confidence: 3.286, Avg Minimum Dist: 9.191:  55%|█████▌    | 33/60 [01:01<00:56,  2.10s/it]
# Avg Confidence: 3.286, Avg Minimum Dist: 9.191:  57%|█████▋    | 34/60 [01:01<00:47,  1.84s/it]
# Avg Confidence: 3.207, Avg Minimum Dist: 9.304:  57%|█████▋    | 34/60 [01:03<00:47,  1.84s/it]
# Avg Confidence: 3.207, Avg Minimum Dist: 9.304:  57%|█████▋    | 34/60 [01:03<00:47,  1.84s/it]
# Avg Confidence: 3.207, Avg Minimum Dist: 9.304:  58%|█████▊    | 35/60 [01:03<00:48,  1.93s/it]
# Avg Confidence: 3.237, Avg Minimum Dist: 9.265:  58%|█████▊    | 35/60 [01:05<00:48,  1.93s/it]
# Avg Confidence: 3.237, Avg Minimum Dist: 9.265:  58%|█████▊    | 35/60 [01:05<00:48,  1.93s/it]
# Avg Confidence: 3.237, Avg Minimum Dist: 9.265:  60%|██████    | 36/60 [01:05<00:44,  1.84s/it]
# Avg Confidence: 3.246, Avg Minimum Dist: 9.276:  60%|██████    | 36/60 [01:07<00:44,  1.84s/it]
# Avg Confidence: 3.246, Avg Minimum Dist: 9.276:  60%|██████    | 36/60 [01:07<00:44,  1.84s/it]
# Avg Confidence: 3.246, Avg Minimum Dist: 9.276:  62%|██████▏   | 37/60 [01:07<00:40,  1.76s/it]
# Avg Confidence: 3.246, Avg Minimum Dist: 9.26:  62%|██████▏   | 37/60 [01:09<00:40,  1.76s/it]
# Avg Confidence: 3.246, Avg Minimum Dist: 9.26:  62%|██████▏   | 37/60 [01:09<00:40,  1.76s/it]
# Avg Confidence: 3.246, Avg Minimum Dist: 9.26:  63%|██████▎   | 38/60 [01:09<00:40,  1.82s/it]
# Avg Confidence: 3.264, Avg Minimum Dist: 9.219:  63%|██████▎   | 38/60 [01:10<00:40,  1.82s/it]
# Avg Confidence: 3.264, Avg Minimum Dist: 9.219:  63%|██████▎   | 38/60 [01:10<00:40,  1.82s/it]
# Avg Confidence: 3.264, Avg Minimum Dist: 9.219:  65%|██████▌   | 39/60 [01:10<00:36,  1.74s/it]
# Avg Confidence: 3.339, Avg Minimum Dist: 9.167:  65%|██████▌   | 39/60 [01:12<00:36,  1.74s/it]
# Avg Confidence: 3.339, Avg Minimum Dist: 9.167:  65%|██████▌   | 39/60 [01:12<00:36,  1.74s/it]
# Avg Confidence: 3.339, Avg Minimum Dist: 9.167:  67%|██████▋   | 40/60 [01:12<00:35,  1.77s/it]
# Avg Confidence: 3.327, Avg Minimum Dist: 9.163:  67%|██████▋   | 40/60 [01:14<00:35,  1.77s/it]
# Avg Confidence: 3.327, Avg Minimum Dist: 9.163:  67%|██████▋   | 40/60 [01:14<00:35,  1.77s/it]
# Avg Confidence: 3.327, Avg Minimum Dist: 9.163:  68%|██████▊   | 41/60 [01:14<00:37,  1.95s/it]
# Avg Confidence: 3.311, Avg Minimum Dist: 9.178:  68%|██████▊   | 41/60 [01:17<00:37,  1.95s/it]
# Avg Confidence: 3.311, Avg Minimum Dist: 9.178:  68%|██████▊   | 41/60 [01:17<00:37,  1.95s/it]
# Avg Confidence: 3.311, Avg Minimum Dist: 9.178:  70%|███████   | 42/60 [01:17<00:39,  2.17s/it]
# Avg Confidence: 3.308, Avg Minimum Dist: 9.16:  70%|███████   | 42/60 [01:20<00:39,  2.17s/it]
# Avg Confidence: 3.308, Avg Minimum Dist: 9.16:  70%|███████   | 42/60 [01:20<00:39,  2.17s/it]
# Avg Confidence: 3.308, Avg Minimum Dist: 9.16:  72%|███████▏  | 43/60 [01:20<00:38,  2.27s/it]
# Avg Confidence: 3.294, Avg Minimum Dist: 9.173:  72%|███████▏  | 43/60 [01:21<00:38,  2.27s/it]
# Avg Confidence: 3.294, Avg Minimum Dist: 9.173:  72%|███████▏  | 43/60 [01:21<00:38,  2.27s/it]
# Avg Confidence: 3.294, Avg Minimum Dist: 9.173:  73%|███████▎  | 44/60 [01:21<00:31,  1.95s/it]
# Avg Confidence: 3.273, Avg Minimum Dist: 9.184:  73%|███████▎  | 44/60 [01:22<00:31,  1.95s/it]
# Avg Confidence: 3.273, Avg Minimum Dist: 9.184:  73%|███████▎  | 44/60 [01:22<00:31,  1.95s/it]
# Avg Confidence: 3.273, Avg Minimum Dist: 9.184:  75%|███████▌  | 45/60 [01:22<00:27,  1.86s/it]
# Avg Confidence: 3.282, Avg Minimum Dist: 9.205:  75%|███████▌  | 45/60 [01:24<00:27,  1.86s/it]
# Avg Confidence: 3.282, Avg Minimum Dist: 9.205:  75%|███████▌  | 45/60 [01:24<00:27,  1.86s/it]
# Avg Confidence: 3.282, Avg Minimum Dist: 9.205:  77%|███████▋  | 46/60 [01:24<00:25,  1.80s/it]
# Avg Confidence: 3.331, Avg Minimum Dist: 9.159:  77%|███████▋  | 46/60 [01:26<00:25,  1.80s/it]
# Avg Confidence: 3.331, Avg Minimum Dist: 9.159:  77%|███████▋  | 46/60 [01:26<00:25,  1.80s/it]
# Avg Confidence: 3.331, Avg Minimum Dist: 9.159:  78%|███████▊  | 47/60 [01:26<00:23,  1.77s/it]
# Avg Confidence: 3.32, Avg Minimum Dist: 9.145:  78%|███████▊  | 47/60 [01:28<00:23,  1.77s/it]
# Avg Confidence: 3.32, Avg Minimum Dist: 9.145:  78%|███████▊  | 47/60 [01:28<00:23,  1.77s/it]
# Avg Confidence: 3.32, Avg Minimum Dist: 9.145:  80%|████████  | 48/60 [01:28<00:21,  1.82s/it]
# Avg Confidence: 3.325, Avg Minimum Dist: 9.094:  80%|████████  | 48/60 [01:29<00:21,  1.82s/it]
# Avg Confidence: 3.325, Avg Minimum Dist: 9.094:  80%|████████  | 48/60 [01:29<00:21,  1.82s/it]
# Avg Confidence: 3.325, Avg Minimum Dist: 9.094:  82%|████████▏ | 49/60 [01:29<00:19,  1.76s/it]
# Avg Confidence: 3.331, Avg Minimum Dist: 9.08:  82%|████████▏ | 49/60 [01:32<00:19,  1.76s/it]
# Avg Confidence: 3.331, Avg Minimum Dist: 9.08:  82%|████████▏ | 49/60 [01:32<00:19,  1.76s/it]
# Avg Confidence: 3.331, Avg Minimum Dist: 9.08:  83%|████████▎ | 50/60 [01:32<00:18,  1.89s/it]
# Avg Confidence: 3.309, Avg Minimum Dist: 9.109:  83%|████████▎ | 50/60 [01:34<00:18,  1.89s/it]
# Avg Confidence: 3.309, Avg Minimum Dist: 9.109:  83%|████████▎ | 50/60 [01:34<00:18,  1.89s/it]
# Avg Confidence: 3.309, Avg Minimum Dist: 9.109:  85%|████████▌ | 51/60 [01:34<00:17,  1.92s/it]
# Avg Confidence: 3.3, Avg Minimum Dist: 9.136:  85%|████████▌ | 51/60 [01:35<00:17,  1.92s/it]
# Avg Confidence: 3.3, Avg Minimum Dist: 9.136:  85%|████████▌ | 51/60 [01:35<00:17,  1.92s/it]
# Avg Confidence: 3.3, Avg Minimum Dist: 9.136:  87%|████████▋ | 52/60 [01:35<00:14,  1.78s/it]
# Avg Confidence: 3.299, Avg Minimum Dist: 9.125:  87%|████████▋ | 52/60 [01:37<00:14,  1.78s/it]
# Avg Confidence: 3.299, Avg Minimum Dist: 9.125:  87%|████████▋ | 52/60 [01:37<00:14,  1.78s/it]
# Avg Confidence: 3.299, Avg Minimum Dist: 9.125:  88%|████████▊ | 53/60 [01:37<00:12,  1.84s/it]
# Avg Confidence: 3.274, Avg Minimum Dist: 9.183:  88%|████████▊ | 53/60 [01:39<00:12,  1.84s/it]
# Avg Confidence: 3.274, Avg Minimum Dist: 9.183:  88%|████████▊ | 53/60 [01:39<00:12,  1.84s/it]
# Avg Confidence: 3.274, Avg Minimum Dist: 9.183:  90%|█████████ | 54/60 [01:39<00:11,  1.87s/it]
# Avg Confidence: 3.265, Avg Minimum Dist: 9.189:  90%|█████████ | 54/60 [01:40<00:11,  1.87s/it]
# Avg Confidence: 3.265, Avg Minimum Dist: 9.189:  90%|█████████ | 54/60 [01:40<00:11,  1.87s/it]
# Avg Confidence: 3.265, Avg Minimum Dist: 9.189:  92%|█████████▏| 55/60 [01:40<00:08,  1.76s/it]
# Avg Confidence: 3.263, Avg Minimum Dist: 9.215:  92%|█████████▏| 55/60 [01:42<00:08,  1.76s/it]
# Avg Confidence: 3.263, Avg Minimum Dist: 9.215:  92%|█████████▏| 55/60 [01:42<00:08,  1.76s/it]
# Avg Confidence: 3.263, Avg Minimum Dist: 9.215:  93%|█████████▎| 56/60 [01:42<00:07,  1.87s/it]
# Avg Confidence: 3.239, Avg Minimum Dist: 9.222:  93%|█████████▎| 56/60 [01:44<00:07,  1.87s/it]
# Avg Confidence: 3.239, Avg Minimum Dist: 9.222:  93%|█████████▎| 56/60 [01:44<00:07,  1.87s/it]
# Avg Confidence: 3.239, Avg Minimum Dist: 9.222:  95%|█████████▌| 57/60 [01:44<00:05,  1.80s/it]
# Avg Confidence: 3.244, Avg Minimum Dist: 9.216:  95%|█████████▌| 57/60 [01:47<00:05,  1.80s/it]
# Avg Confidence: 3.244, Avg Minimum Dist: 9.216:  95%|█████████▌| 57/60 [01:47<00:05,  1.80s/it]
# Avg Confidence: 3.244, Avg Minimum Dist: 9.216:  97%|█████████▋| 58/60 [01:47<00:03,  1.97s/it]
# Avg Confidence: 3.232, Avg Minimum Dist: 9.237:  97%|█████████▋| 58/60 [01:48<00:03,  1.97s/it]
# Avg Confidence: 3.232, Avg Minimum Dist: 9.237:  97%|█████████▋| 58/60 [01:48<00:03,  1.97s/it]
# Avg Confidence: 3.232, Avg Minimum Dist: 9.237:  98%|█████████▊| 59/60 [01:48<00:01,  1.82s/it]
# Avg Confidence: 3.253, Avg Minimum Dist: 9.225:  98%|█████████▊| 59/60 [01:49<00:01,  1.82s/it]
# Avg Confidence: 3.253, Avg Minimum Dist: 9.225:  98%|█████████▊| 59/60 [01:49<00:01,  1.82s/it]
# Avg Confidence: 3.253, Avg Minimum Dist: 9.225: 100%|██████████| 60/60 [01:49<00:00,  1.71s/it]
# Avg Confidence: 3.253, Avg Minimum Dist: 9.225: 100%|██████████| 60/60 [01:49<00:00,  1.83s/it]
#
#
# VCTK_v15 Results:
#   Average Confidence (LSE-C): 3.2529
#   Average Minimum Distance (LSE-D): 9.2247
#
# VCTK_v15 Overall Scores:
#   LSE-C (Confidence): 3.2529
#   LSE-D (Distance): 9.2247
#   Total 512 res files processed: 60
# Sample files processed:
#   1. A008_02_BBP_NORMAL_color_25fps_6sec_YT_A008_cloned_512.mp4
#   2. A006_02_BBP_NORMAL_color_25fps_6sec_YT_A006_cloned_512.mp4
#   3. A015_02_DDK_PATAKA_color_25fps_6sec_XT_A015_cloned_512.mp4
#   4. S001_02_DDK_PA_color_25fps_6sec_YT_S001_cloned_512.mp4
#   5. S012_02_BBP_NORMAL_color_25fps_6sec_YT_S012_cloned_512.mp4
#
# Processing RAW_avatar dataset...
# Folder: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/edtalk-exp/EDTalk/results/test_raw/avatar/RAW
# Calculating LSE scores for RAW_avatar videos in: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/edtalk-exp/EDTalk/results/test_raw/avatar/RAW
# Created temp folder with 60 files
# Running command: python calculate_scores_LRS.py --data_root temp_512_RAW_avatar --tmp_dir tmp_dir_RAW_avatar
# STDOUT: Average Confidence: 4.456900191307068
# Average Minimum Distance: 9.095940446853637
#
# STDERR:
#   0%|          | 0/60 [00:00<?, ?it/s]
# Avg Confidence: 8.948, Avg Minimum Dist: 6.896:   0%|          | 0/60 [00:02<?, ?it/s]
# Avg Confidence: 8.948, Avg Minimum Dist: 6.896:   0%|          | 0/60 [00:02<?, ?it/s]
# Avg Confidence: 8.948, Avg Minimum Dist: 6.896:   2%|▏         | 1/60 [00:02<02:09,  2.20s/it]
# Avg Confidence: 8.078, Avg Minimum Dist: 7.158:   2%|▏         | 1/60 [00:04<02:09,  2.20s/it]
# Avg Confidence: 8.078, Avg Minimum Dist: 7.158:   2%|▏         | 1/60 [00:04<02:09,  2.20s/it]
# Avg Confidence: 8.078, Avg Minimum Dist: 7.158:   3%|▎         | 2/60 [00:04<02:07,  2.20s/it]
# Avg Confidence: 7.388, Avg Minimum Dist: 6.816:   3%|▎         | 2/60 [00:05<02:07,  2.20s/it]
# Avg Confidence: 7.388, Avg Minimum Dist: 6.816:   3%|▎         | 2/60 [00:05<02:07,  2.20s/it]
# Avg Confidence: 7.388, Avg Minimum Dist: 6.816:   5%|▌         | 3/60 [00:05<01:40,  1.77s/it]
# Avg Confidence: 6.591, Avg Minimum Dist: 7.102:   5%|▌         | 3/60 [00:07<01:40,  1.77s/it]
# Avg Confidence: 6.591, Avg Minimum Dist: 7.102:   5%|▌         | 3/60 [00:07<01:40,  1.77s/it]
# Avg Confidence: 6.591, Avg Minimum Dist: 7.102:   7%|▋         | 4/60 [00:07<01:46,  1.91s/it]
# Avg Confidence: 5.937, Avg Minimum Dist: 7.539:   7%|▋         | 4/60 [00:10<01:46,  1.91s/it]
# Avg Confidence: 5.937, Avg Minimum Dist: 7.539:   7%|▋         | 4/60 [00:10<01:46,  1.91s/it]
# Avg Confidence: 5.937, Avg Minimum Dist: 7.539:   8%|▊         | 5/60 [00:10<01:53,  2.06s/it]
# Avg Confidence: 5.394, Avg Minimum Dist: 8.02:   8%|▊         | 5/60 [00:12<01:53,  2.06s/it]
# Avg Confidence: 5.394, Avg Minimum Dist: 8.02:   8%|▊         | 5/60 [00:12<01:53,  2.06s/it]
# Avg Confidence: 5.394, Avg Minimum Dist: 8.02:  10%|█         | 6/60 [00:12<01:59,  2.22s/it]
# Avg Confidence: 5.034, Avg Minimum Dist: 8.441:  10%|█         | 6/60 [00:14<01:59,  2.22s/it]
# Avg Confidence: 5.034, Avg Minimum Dist: 8.441:  10%|█         | 6/60 [00:14<01:59,  2.22s/it]
# Avg Confidence: 5.034, Avg Minimum Dist: 8.441:  12%|█▏        | 7/60 [00:14<01:50,  2.08s/it]
# Avg Confidence: 5.015, Avg Minimum Dist: 8.521:  12%|█▏        | 7/60 [00:15<01:50,  2.08s/it]
# Avg Confidence: 5.015, Avg Minimum Dist: 8.521:  12%|█▏        | 7/60 [00:15<01:50,  2.08s/it]
# Avg Confidence: 5.015, Avg Minimum Dist: 8.521:  13%|█▎        | 8/60 [00:15<01:39,  1.91s/it]
# Avg Confidence: 5.075, Avg Minimum Dist: 8.526:  13%|█▎        | 8/60 [00:18<01:39,  1.91s/it]
# Avg Confidence: 5.075, Avg Minimum Dist: 8.526:  13%|█▎        | 8/60 [00:18<01:39,  1.91s/it]
# Avg Confidence: 5.075, Avg Minimum Dist: 8.526:  15%|█▌        | 9/60 [00:18<01:44,  2.05s/it]
# Avg Confidence: 5.136, Avg Minimum Dist: 8.525:  15%|█▌        | 9/60 [00:21<01:44,  2.05s/it]
# Avg Confidence: 5.136, Avg Minimum Dist: 8.525:  15%|█▌        | 9/60 [00:21<01:44,  2.05s/it]
# Avg Confidence: 5.136, Avg Minimum Dist: 8.525:  17%|█▋        | 10/60 [00:21<01:57,  2.35s/it]
# Avg Confidence: 5.399, Avg Minimum Dist: 8.351:  17%|█▋        | 10/60 [00:23<01:57,  2.35s/it]
# Avg Confidence: 5.399, Avg Minimum Dist: 8.351:  17%|█▋        | 10/60 [00:23<01:57,  2.35s/it]
# Avg Confidence: 5.399, Avg Minimum Dist: 8.351:  18%|█▊        | 11/60 [00:23<01:55,  2.36s/it]
# Avg Confidence: 5.615, Avg Minimum Dist: 8.279:  18%|█▊        | 11/60 [00:26<01:55,  2.36s/it]
# Avg Confidence: 5.615, Avg Minimum Dist: 8.279:  18%|█▊        | 11/60 [00:26<01:55,  2.36s/it]
# Avg Confidence: 5.615, Avg Minimum Dist: 8.279:  20%|██        | 12/60 [00:26<02:04,  2.60s/it]
# Avg Confidence: 5.639, Avg Minimum Dist: 8.263:  20%|██        | 12/60 [00:29<02:04,  2.60s/it]
# Avg Confidence: 5.639, Avg Minimum Dist: 8.263:  20%|██        | 12/60 [00:29<02:04,  2.60s/it]
# Avg Confidence: 5.639, Avg Minimum Dist: 8.263:  22%|██▏       | 13/60 [00:29<02:07,  2.71s/it]
# Avg Confidence: 5.636, Avg Minimum Dist: 8.299:  22%|██▏       | 13/60 [00:31<02:07,  2.71s/it]
# Avg Confidence: 5.636, Avg Minimum Dist: 8.299:  22%|██▏       | 13/60 [00:31<02:07,  2.71s/it]
# Avg Confidence: 5.636, Avg Minimum Dist: 8.299:  23%|██▎       | 14/60 [00:31<01:48,  2.35s/it]
# Avg Confidence: 5.515, Avg Minimum Dist: 8.113:  23%|██▎       | 14/60 [00:33<01:48,  2.35s/it]
# Avg Confidence: 5.515, Avg Minimum Dist: 8.113:  23%|██▎       | 14/60 [00:33<01:48,  2.35s/it]
# Avg Confidence: 5.515, Avg Minimum Dist: 8.113:  25%|██▌       | 15/60 [00:33<01:36,  2.14s/it]
# Avg Confidence: 5.558, Avg Minimum Dist: 8.099:  25%|██▌       | 15/60 [00:34<01:36,  2.14s/it]
# Avg Confidence: 5.558, Avg Minimum Dist: 8.099:  25%|██▌       | 15/60 [00:34<01:36,  2.14s/it]
# Avg Confidence: 5.558, Avg Minimum Dist: 8.099:  27%|██▋       | 16/60 [00:34<01:26,  1.97s/it]
# Avg Confidence: 5.394, Avg Minimum Dist: 8.246:  27%|██▋       | 16/60 [00:36<01:26,  1.97s/it]
# Avg Confidence: 5.394, Avg Minimum Dist: 8.246:  27%|██▋       | 16/60 [00:36<01:26,  1.97s/it]
# Avg Confidence: 5.394, Avg Minimum Dist: 8.246:  28%|██▊       | 17/60 [00:36<01:20,  1.87s/it]
# Avg Confidence: 5.311, Avg Minimum Dist: 8.299:  28%|██▊       | 17/60 [00:38<01:20,  1.87s/it]
# Avg Confidence: 5.311, Avg Minimum Dist: 8.299:  28%|██▊       | 17/60 [00:38<01:20,  1.87s/it]
# Avg Confidence: 5.311, Avg Minimum Dist: 8.299:  30%|███       | 18/60 [00:38<01:19,  1.89s/it]
# Avg Confidence: 5.175, Avg Minimum Dist: 8.389:  30%|███       | 18/60 [00:40<01:19,  1.89s/it]
# Avg Confidence: 5.175, Avg Minimum Dist: 8.389:  30%|███       | 18/60 [00:40<01:19,  1.89s/it]
# Avg Confidence: 5.175, Avg Minimum Dist: 8.389:  32%|███▏      | 19/60 [00:40<01:24,  2.05s/it]
# Avg Confidence: 5.014, Avg Minimum Dist: 8.547:  32%|███▏      | 19/60 [00:42<01:24,  2.05s/it]
# Avg Confidence: 5.014, Avg Minimum Dist: 8.547:  32%|███▏      | 19/60 [00:42<01:24,  2.05s/it]
# Avg Confidence: 5.014, Avg Minimum Dist: 8.547:  33%|███▎      | 20/60 [00:42<01:17,  1.93s/it]
# Avg Confidence: 5.088, Avg Minimum Dist: 8.517:  33%|███▎      | 20/60 [00:44<01:17,  1.93s/it]
# Avg Confidence: 5.088, Avg Minimum Dist: 8.517:  33%|███▎      | 20/60 [00:44<01:17,  1.93s/it]
# Avg Confidence: 5.088, Avg Minimum Dist: 8.517:  35%|███▌      | 21/60 [00:44<01:22,  2.13s/it]
# Avg Confidence: 5.137, Avg Minimum Dist: 8.513:  35%|███▌      | 21/60 [00:46<01:22,  2.13s/it]
# Avg Confidence: 5.137, Avg Minimum Dist: 8.513:  35%|███▌      | 21/60 [00:46<01:22,  2.13s/it]
# Avg Confidence: 5.137, Avg Minimum Dist: 8.513:  37%|███▋      | 22/60 [00:46<01:19,  2.10s/it]
# Avg Confidence: 5.253, Avg Minimum Dist: 8.437:  37%|███▋      | 22/60 [00:48<01:19,  2.10s/it]
# Avg Confidence: 5.253, Avg Minimum Dist: 8.437:  37%|███▋      | 22/60 [00:48<01:19,  2.10s/it]
# Avg Confidence: 5.253, Avg Minimum Dist: 8.437:  38%|███▊      | 23/60 [00:48<01:11,  1.94s/it]
# Avg Confidence: 5.358, Avg Minimum Dist: 8.344:  38%|███▊      | 23/60 [00:52<01:11,  1.94s/it]
# Avg Confidence: 5.358, Avg Minimum Dist: 8.344:  38%|███▊      | 23/60 [00:52<01:11,  1.94s/it]
# Avg Confidence: 5.358, Avg Minimum Dist: 8.344:  40%|████      | 24/60 [00:52<01:31,  2.55s/it]
# Avg Confidence: 5.228, Avg Minimum Dist: 8.408:  40%|████      | 24/60 [00:56<01:31,  2.55s/it]
# Avg Confidence: 5.228, Avg Minimum Dist: 8.408:  40%|████      | 24/60 [00:56<01:31,  2.55s/it]
# Avg Confidence: 5.228, Avg Minimum Dist: 8.408:  42%|████▏     | 25/60 [00:56<01:44,  2.99s/it]
# Avg Confidence: 5.05, Avg Minimum Dist: 8.562:  42%|████▏     | 25/60 [00:59<01:44,  2.99s/it]
# Avg Confidence: 5.05, Avg Minimum Dist: 8.562:  42%|████▏     | 25/60 [00:59<01:44,  2.99s/it]
# Avg Confidence: 5.05, Avg Minimum Dist: 8.562:  43%|████▎     | 26/60 [00:59<01:40,  2.95s/it]
# Avg Confidence: 4.95, Avg Minimum Dist: 8.648:  43%|████▎     | 26/60 [01:01<01:40,  2.95s/it]
# Avg Confidence: 4.95, Avg Minimum Dist: 8.648:  43%|████▎     | 26/60 [01:01<01:40,  2.95s/it]
# Avg Confidence: 4.95, Avg Minimum Dist: 8.648:  45%|████▌     | 27/60 [01:01<01:28,  2.69s/it]
# Avg Confidence: 4.818, Avg Minimum Dist: 8.751:  45%|████▌     | 27/60 [01:04<01:28,  2.69s/it]
# Avg Confidence: 4.818, Avg Minimum Dist: 8.751:  45%|████▌     | 27/60 [01:04<01:28,  2.69s/it]
# Avg Confidence: 4.818, Avg Minimum Dist: 8.751:  47%|████▋     | 28/60 [01:04<01:28,  2.78s/it]
# Avg Confidence: 4.794, Avg Minimum Dist: 8.797:  47%|████▋     | 28/60 [01:10<01:28,  2.78s/it]
# Avg Confidence: 4.794, Avg Minimum Dist: 8.797:  47%|████▋     | 28/60 [01:10<01:28,  2.78s/it]
# Avg Confidence: 4.794, Avg Minimum Dist: 8.797:  48%|████▊     | 29/60 [01:10<01:54,  3.68s/it]
# Avg Confidence: 4.914, Avg Minimum Dist: 8.733:  48%|████▊     | 29/60 [01:13<01:54,  3.68s/it]
# Avg Confidence: 4.914, Avg Minimum Dist: 8.733:  48%|████▊     | 29/60 [01:13<01:54,  3.68s/it]
# Avg Confidence: 4.914, Avg Minimum Dist: 8.733:  50%|█████     | 30/60 [01:13<01:43,  3.46s/it]
# Avg Confidence: 4.88, Avg Minimum Dist: 8.681:  50%|█████     | 30/60 [01:14<01:43,  3.46s/it]
# Avg Confidence: 4.88, Avg Minimum Dist: 8.681:  50%|█████     | 30/60 [01:14<01:43,  3.46s/it]
# Avg Confidence: 4.88, Avg Minimum Dist: 8.681:  52%|█████▏    | 31/60 [01:14<01:21,  2.82s/it]
# Avg Confidence: 4.977, Avg Minimum Dist: 8.626:  52%|█████▏    | 31/60 [01:16<01:21,  2.82s/it]
# Avg Confidence: 4.977, Avg Minimum Dist: 8.626:  52%|█████▏    | 31/60 [01:16<01:21,  2.82s/it]
# Avg Confidence: 4.977, Avg Minimum Dist: 8.626:  53%|█████▎    | 32/60 [01:16<01:13,  2.64s/it]
# Avg Confidence: 4.905, Avg Minimum Dist: 8.654:  53%|█████▎    | 32/60 [01:19<01:13,  2.64s/it]
# Avg Confidence: 4.905, Avg Minimum Dist: 8.654:  53%|█████▎    | 32/60 [01:19<01:13,  2.64s/it]
# Avg Confidence: 4.905, Avg Minimum Dist: 8.654:  55%|█████▌    | 33/60 [01:19<01:11,  2.66s/it]
# Avg Confidence: 4.793, Avg Minimum Dist: 8.744:  55%|█████▌    | 33/60 [01:22<01:11,  2.66s/it]
# Avg Confidence: 4.793, Avg Minimum Dist: 8.744:  55%|█████▌    | 33/60 [01:22<01:11,  2.66s/it]
# Avg Confidence: 4.793, Avg Minimum Dist: 8.744:  57%|█████▋    | 34/60 [01:22<01:11,  2.76s/it]
# Avg Confidence: 4.7, Avg Minimum Dist: 8.881:  57%|█████▋    | 34/60 [01:23<01:11,  2.76s/it]
# Avg Confidence: 4.7, Avg Minimum Dist: 8.881:  57%|█████▋    | 34/60 [01:23<01:11,  2.76s/it]
# Avg Confidence: 4.7, Avg Minimum Dist: 8.881:  58%|█████▊    | 35/60 [01:23<01:00,  2.41s/it]
# Avg Confidence: 4.762, Avg Minimum Dist: 8.837:  58%|█████▊    | 35/60 [01:25<01:00,  2.41s/it]
# Avg Confidence: 4.762, Avg Minimum Dist: 8.837:  58%|█████▊    | 35/60 [01:25<01:00,  2.41s/it]
# ...
#   LSE-C: 4.2118 ± 0.0000
#
# VCTK_avatar_S008 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 8.7952 ± 0.0000
#   LSE-C: 4.2118 ± 0.0000
#
# VCTK_avatar_S009 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 8.7952 ± 0.0000
#   LSE-C: 4.2118 ± 0.0000
#
# VCTK_avatar_S011 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 8.7952 ± 0.0000
#   LSE-C: 4.2118 ± 0.0000
#
# VCTK_avatar_S012 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 8.7952 ± 0.0000
#   LSE-C: 4.2118 ± 0.0000
#
# VCTK_avatar_S013 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 8.7952 ± 0.0000
#   LSE-C: 4.2118 ± 0.0000
#
# VCTK_v15_A002 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_A006 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_A008 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_A010 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_A011 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_A014 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_A015 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_A016 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_A017 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_S001 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_S002 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_S003 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_S005 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_S006 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_S007 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_S008 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_S009 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_S011 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_S012 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK_v15_S013 (3 samples, TTS: XTTSv2, CosyVoice, YourTTS):
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# ======================================================================
# SUMMARY TABLES
# ======================================================================
#
# Summary by Dataset, Data Type and TTS Method:
# Dataset Data_Type TTS_Method  Count  LSE_D_Mean  LSE_D_Std  LSE_C_Mean  LSE_C_Std
#     RAW       v15  CosyVoice     20      9.9286        0.0      2.9676        0.0
#     RAW       v15     XTTSv2     20      9.9286        0.0      2.9676        0.0
#     RAW       v15    YourTTS     20      9.9286        0.0      2.9676        0.0
#     RAW    avatar  CosyVoice     20      9.0959        0.0      4.4569        0.0
#     RAW    avatar     XTTSv2     20      9.0959        0.0      4.4569        0.0
#     RAW    avatar    YourTTS     20      9.0959        0.0      4.4569        0.0
#    VCTK       v15  CosyVoice     20      9.2247        0.0      3.2529        0.0
#    VCTK       v15     XTTSv2     20      9.2247        0.0      3.2529        0.0
#    VCTK       v15    YourTTS     20      9.2247        0.0      3.2529        0.0
#    VCTK    avatar  CosyVoice     20      8.7952        0.0      4.2118        0.0
#    VCTK    avatar     XTTSv2     20      8.7952        0.0      4.2118        0.0
#    VCTK    avatar    YourTTS     20      8.7952        0.0      4.2118        0.0
#
# Summary by Speaker:
# Dataset Data_Type Speaker_ID  Count  LSE_D_Mean  LSE_D_Std  LSE_C_Mean  LSE_C_Std                TTS_Methods
#     RAW    avatar       A002      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       A006      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       A008      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       A010      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       A011      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       A014      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       A015      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       A016      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       A017      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       S001      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       S002      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       S003      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       S005      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       S006      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       S007      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       S008      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       S009      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       S011      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       S012      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW    avatar       S013      3      9.0959        0.0      4.4569        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       A002      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       A006      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       A008      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       A010      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       A011      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       A014      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       A015      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       A016      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       A017      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       S001      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       S002      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       S003      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       S005      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       S006      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       S007      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       S008      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       S009      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       S011      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       S012      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#     RAW       v15       S013      3      9.9286        0.0      2.9676        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       A002      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       A006      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       A008      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       A010      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       A011      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       A014      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       A015      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       A016      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       A017      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       S001      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       S002      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       S003      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       S005      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       S006      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       S007      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       S008      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       S009      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       S011      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       S012      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK    avatar       S013      3      8.7952        0.0      4.2118        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       A002      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       A006      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       A008      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       A010      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       A011      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       A014      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       A015      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       A016      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       A017      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       S001      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       S002      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       S003      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       S005      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       S006      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       S007      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       S008      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       S009      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       S011      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       S012      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#    VCTK       v15       S013      3      9.2247        0.0      3.2529        0.0 XTTSv2, CosyVoice, YourTTS
#
# ======================================================================
# OVERALL STATISTICS PER DATASET AND DATA TYPE
# ======================================================================
#
# RAW - V15 Dataset (512 resolution):
#   Total samples: 60
#   LSE-D: 9.9286 ± 0.0000
#   LSE-C: 2.9676 ± 0.0000
#
# RAW - Avatar Dataset (512 resolution):
#   Total samples: 60
#   LSE-D: 9.0959 ± 0.0000
#   LSE-C: 4.4569 ± 0.0000
#
# VCTK - V15 Dataset (512 resolution):
#   Total samples: 60
#   LSE-D: 9.2247 ± 0.0000
#   LSE-C: 3.2529 ± 0.0000
#
# VCTK - Avatar Dataset (512 resolution):
#   Total samples: 60
#   LSE-D: 8.7952 ± 0.0000
#   LSE-C: 4.2118 ± 0.0000
#
# ======================================================================
# AVATAR vs V15 COMPARISON
# ======================================================================
#
# RAW - CosyVoice:
#   V15    - LSE-D: 9.9286, LSE-C: 2.9676
#   Avatar - LSE-D: 9.0959, LSE-C: 4.4569
#   Improvement (D): +0.8326
#   Improvement (C): +1.4893
#
# RAW - XTTSv2:
#   V15    - LSE-D: 9.9286, LSE-C: 2.9676
#   Avatar - LSE-D: 9.0959, LSE-C: 4.4569
#   Improvement (D): +0.8326
#   Improvement (C): +1.4893
#
# RAW - YourTTS:
#   V15    - LSE-D: 9.9286, LSE-C: 2.9676
#   Avatar - LSE-D: 9.0959, LSE-C: 4.4569
#   Improvement (D): +0.8326
#   Improvement (C): +1.4893
#
# VCTK - CosyVoice:
#   V15    - LSE-D: 9.2247, LSE-C: 3.2529
#   Avatar - LSE-D: 8.7952, LSE-C: 4.2118
#   Improvement (D): +0.4295
#   Improvement (C): +0.9589
#
# VCTK - XTTSv2:
#   V15    - LSE-D: 9.2247, LSE-C: 3.2529
#   Avatar - LSE-D: 8.7952, LSE-C: 4.2118
#   Improvement (D): +0.4295
#   Improvement (C): +0.9589
#
# VCTK - YourTTS:
#   V15    - LSE-D: 9.2247, LSE-C: 3.2529
#   Avatar - LSE-D: 8.7952, LSE-C: 4.2118
#   Improvement (D): +0.4295
#   Improvement (C): +0.9589
#
# Detailed Avatar vs V15 Comparison:
# Dataset TTS_Method  V15_LSE_D  V15_LSE_C  Avatar_LSE_D  Avatar_LSE_C  LSE_D_Improvement  LSE_C_Improvement
#     RAW  CosyVoice     9.9286     2.9676        9.0959        4.4569             0.8326             1.4893
#     RAW     XTTSv2     9.9286     2.9676        9.0959        4.4569             0.8326             1.4893
#     RAW    YourTTS     9.9286     2.9676        9.0959        4.4569             0.8326             1.4893
#    VCTK  CosyVoice     9.2247     3.2529        8.7952        4.2118             0.4295             0.9589
#    VCTK     XTTSv2     9.2247     3.2529        8.7952        4.2118             0.4295             0.9589
#    VCTK    YourTTS     9.2247     3.2529        8.7952        4.2118             0.4295             0.9589
#
# Detailed results saved to: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_results_lse_edtalk.csv
# TTS summary saved to: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_summary_lse_edtalk_tts.csv
# Speaker summary saved to: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_summary_lse_edtalk_speaker.csv
# Avatar vs V15 comparison saved to: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_comparison_avatar_v15.csv
#
# EDTalk LSE evaluation completed successfully!

# %%
# Disease-based LSE-C Evaluation Script
import pandas as pd
import numpy as np
import os

def load_lse_results():
    """Load all existing LSE evaluation CSV files"""
    results = {}
    
    # MuseTalk LSE results
    musetalk_lse = "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_results_lse.csv"
    
    # EDTalk LSE results
    edtalk_lse = "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/evaluation_results_lse_edtalk.csv"
    
    # Load MuseTalk LSE
    if os.path.exists(musetalk_lse):
        df = pd.read_csv(musetalk_lse)
        df['model'] = 'MuseTalk'
        df['data_type'] = 'V15'  # MuseTalk only has V15 type
        results['musetalk'] = df
        print(f"Loaded MuseTalk LSE results: {len(df)} records")
    
    # Load EDTalk LSE (contains both V15 and Avatar)
    if os.path.exists(edtalk_lse):
        df = pd.read_csv(edtalk_lse)
        df['model'] = 'EDTalk'
        results['edtalk'] = df
        print(f"Loaded EDTalk LSE results: {len(df)} records")
    
    return results

def get_disease_category(speaker_id):
    """Determine disease category from speaker ID"""
    if speaker_id.startswith('A'):
        return 'ALS'
    elif speaker_id.startswith('S'):
        return 'Stroke'
    else:
        return 'Unknown'

def calculate_lse_disease_metrics(df, model_name):
    """Calculate LSE metrics per disease category"""
    summary_data = []
    
    # Add disease category
    df['disease'] = df['speaker_id'].apply(get_disease_category)
    
    # TTS methods to evaluate
    tts_methods = ['CosyVoice', 'XTTSv2', 'YourTTS']
    
    # Get unique combinations
    unique_combinations = df[['dataset', 'data_type']].drop_duplicates()
    
    for _, combo in unique_combinations.iterrows():
        dataset = combo['dataset']
        data_type = combo['data_type']
        
        combo_data = df[(df['dataset'] == dataset) & (df['data_type'] == data_type)]
        
        for disease in ['ALS', 'Stroke']:
            disease_data = combo_data[combo_data['disease'] == disease]
            
            if len(disease_data) > 0:
                for tts_method in tts_methods:
                    tts_data = disease_data[disease_data['tts_method'] == tts_method]
                    
                    if len(tts_data) > 0:
                        summary_data.append({
                            'Model': model_name,
                            'Dataset': dataset,
                            'Data_Type': data_type,
                            'TTS_Method': tts_method,
                            'Disease': disease,
                            'Count': len(tts_data),
                            'LSE_D_Mean': tts_data['lse_d_score'].mean(),
                            'LSE_D_Std': tts_data['lse_d_score'].std(),
                            'LSE_C_Mean': tts_data['lse_c_score'].mean(),
                            'LSE_C_Std': tts_data['lse_c_score'].std()
                        })
    
    return summary_data

def main_lse_disease_evaluation():
    """Main function to generate disease-based LSE evaluation"""
    print("=" * 80)
    print("LSE-C DISEASE-BASED EVALUATION (ALS vs STROKE)")
    print("=" * 80)
    
    # Load all LSE results
    results = load_lse_results()
    
    all_summaries = []
    
    # Process MuseTalk
    if 'musetalk' in results:
        print("\nProcessing MuseTalk LSE results...")
        summaries = calculate_lse_disease_metrics(results['musetalk'], 'MuseTalk')
        all_summaries.extend(summaries)
        print(f"Generated {len(summaries)} entries")
    
    # Process EDTalk
    if 'edtalk' in results:
        print("\nProcessing EDTalk LSE results...")
        summaries = calculate_lse_disease_metrics(results['edtalk'], 'EDTalk')
        all_summaries.extend(summaries)
        print(f"Generated {len(summaries)} entries")
    
    # Create final summary DataFrame
    if all_summaries:
        final_df = pd.DataFrame(all_summaries)
        
        # Sort for better readability
        final_df = final_df.sort_values(['Model', 'Dataset', 'Data_Type', 'Disease', 'TTS_Method'])
        
        print("\n" + "=" * 80)
        print("FINAL LSE RESEARCH TABLE - DISEASE-BASED METRICS")
        print("=" * 80)
        print(final_df.round(4).to_string(index=False))
        
        # Save to CSV
        output_path = "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/lse_disease_based_evaluation_summary.csv"
        final_df.to_csv(output_path, index=False)
        print(f"\nLSE results saved to: {output_path}")
        
        # Generate summary statistics for research paper
        print("\n" + "=" * 80)
        print("LSE RESEARCH PAPER SUMMARY")
        print("=" * 80)
        
        for model in ['MuseTalk', 'EDTalk']:
            model_data = final_df[final_df['Model'] == model]
            if len(model_data) > 0:
                print(f"\n{model}:")
                
                # For MuseTalk, only V15 exists
                data_types = ['V15'] if model == 'MuseTalk' else ['V15', 'Avatar']
                
                for dataset in ['RAW', 'VCTK']:
                    dataset_data = model_data[model_data['Dataset'] == dataset]
                    if len(dataset_data) > 0:
                        print(f"  {dataset} Dataset:")
                        
                        for data_type in data_types:
                            dtype_data = dataset_data[dataset_data['Data_Type'] == data_type]
                            if len(dtype_data) > 0:
                                print(f"    {data_type}:")
                                
                                for disease in ['ALS', 'Stroke']:
                                    disease_data = dtype_data[dtype_data['Disease'] == disease]
                                    if len(disease_data) > 0:
                                        avg_lse_c = disease_data['LSE_C_Mean'].mean()
                                        avg_lse_d = disease_data['LSE_D_Mean'].mean()
                                        total_samples = disease_data['Count'].sum()
                                        
                                        print(f"      {disease} (Total: {total_samples} samples):")
                                        print(f"        Avg LSE-C across TTS: {avg_lse_c:.4f}")
                                        print(f"        Avg LSE-D across TTS: {avg_lse_d:.4f}")
        
        # Create simplified table format for research paper
        print("\n" + "=" * 80)
        print("SIMPLIFIED LSE TABLE FOR RESEARCH PAPER")
        print("=" * 80)
        
        # Group by Model, Dataset, Data_Type for table format
        table_data = []
        for model in ['MuseTalk', 'EDTalk']:
            for dataset in ['RAW', 'VCTK']:
                data_types = ['V15'] if model == 'MuseTalk' else ['V15', 'Avatar']
                
                for data_type in data_types:
                    model_dataset_data = final_df[
                        (final_df['Model'] == model) & 
                        (final_df['Dataset'] == dataset) & 
                        (final_df['Data_Type'] == data_type)
                    ]
                    
                    if len(model_dataset_data) > 0:
                        # Calculate average across all TTS methods for each disease
                        als_data = model_dataset_data[model_dataset_data['Disease'] == 'ALS']
                        stroke_data = model_dataset_data[model_dataset_data['Disease'] == 'Stroke']
                        
                        row = {
                            'Dataset': dataset,
                            'Model': f"{model}_{data_type}" if model == 'EDTalk' else model,
                            'ALS_LSE_C': als_data['LSE_C_Mean'].mean() if len(als_data) > 0 else 0,
                            'ALS_LSE_D': als_data['LSE_D_Mean'].mean() if len(als_data) > 0 else 0,
                            'ALS_Count': als_data['Count'].sum() if len(als_data) > 0 else 0,
                            'Stroke_LSE_C': stroke_data['LSE_C_Mean'].mean() if len(stroke_data) > 0 else 0,
                            'Stroke_LSE_D': stroke_data['LSE_D_Mean'].mean() if len(stroke_data) > 0 else 0,
                            'Stroke_Count': stroke_data['Count'].sum() if len(stroke_data) > 0 else 0
                        }
                        table_data.append(row)
        
        table_df = pd.DataFrame(table_data)
        if len(table_df) > 0:
            print("\nSIMPLIFIED LSE TABLE (Averaged across TTS methods):")
            print(table_df.round(4).to_string(index=False))
            
            # Save simplified table
            simple_output_path = "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/simplified_lse_disease_table.csv"
            table_df.to_csv(simple_output_path, index=False)
            print(f"\nSimplified LSE table saved to: {simple_output_path}")
        
        # Show comparison between Avatar and V15 for EDTalk
        print("\n" + "=" * 80)
        print("EDTALK: AVATAR vs V15 COMPARISON (LSE-C)")
        print("=" * 80)
        
        edtalk_data = final_df[final_df['Model'] == 'EDTalk']
        comparison_results = []
        
        for dataset in ['RAW', 'VCTK']:
            for disease in ['ALS', 'Stroke']:
                v15_data = edtalk_data[
                    (edtalk_data['Dataset'] == dataset) & 
                    (edtalk_data['Data_Type'] == 'V15') & 
                    (edtalk_data['Disease'] == disease)
                ]
                avatar_data = edtalk_data[
                    (edtalk_data['Dataset'] == dataset) & 
                    (edtalk_data['Data_Type'] == 'Avatar') & 
                    (edtalk_data['Disease'] == disease)
                ]
                
                if len(v15_data) > 0 and len(avatar_data) > 0:
                    v15_lse_c = v15_data['LSE_C_Mean'].mean()
                    avatar_lse_c = avatar_data['LSE_C_Mean'].mean()
                    improvement = avatar_lse_c - v15_lse_c
                    
                    print(f"\n{dataset} - {disease}:")
                    print(f"  V15:    LSE-C = {v15_lse_c:.4f}")
                    print(f"  Avatar: LSE-C = {avatar_lse_c:.4f}")
                    print(f"  Improvement: {improvement:+.4f}")
                    
                    comparison_results.append({
                        'Dataset': dataset,
                        'Disease': disease,
                        'V15_LSE_C': v15_lse_c,
                        'Avatar_LSE_C': avatar_lse_c,
                        'Improvement': improvement
                    })
        
        if comparison_results:
            comparison_df = pd.DataFrame(comparison_results)
            print(f"\nAvatar vs V15 Comparison Summary:")
            print(comparison_df.round(4).to_string(index=False))
        
        # Final table format matching the research table structure
        print("\n" + "=" * 80)
        print("FINAL TABLE FORMAT FOR RESEARCH PAPER (LSE-C only)")
        print("=" * 80)
        
        # Restructure data to match the table format
        research_table_data = []
        
        # MuseTalk
        musetalk_data = final_df[final_df['Model'] == 'MuseTalk']
        for dataset in ['RAW', 'VCTK']:
            dataset_data = musetalk_data[musetalk_data['Dataset'] == dataset]
            if len(dataset_data) > 0:
                als_lse_c = dataset_data[dataset_data['Disease'] == 'ALS']['LSE_C_Mean'].mean()
                stroke_lse_c = dataset_data[dataset_data['Disease'] == 'Stroke']['LSE_C_Mean'].mean()
                
                research_table_data.append({
                    'Dataset': dataset,
                    'Model': 'MuseTalk',
                    'ALS_LSE_C': als_lse_c if not np.isnan(als_lse_c) else 0,
                    'Stroke_LSE_C': stroke_lse_c if not np.isnan(stroke_lse_c) else 0
                })
        
        # EDTalk V15
        edtalk_v15_data = final_df[(final_df['Model'] == 'EDTalk') & (final_df['Data_Type'] == 'V15')]
        for dataset in ['RAW', 'VCTK']:
            dataset_data = edtalk_v15_data[edtalk_v15_data['Dataset'] == dataset]
            if len(dataset_data) > 0:
                als_lse_c = dataset_data[dataset_data['Disease'] == 'ALS']['LSE_C_Mean'].mean()
                stroke_lse_c = dataset_data[dataset_data['Disease'] == 'Stroke']['LSE_C_Mean'].mean()
                
                research_table_data.append({
                    'Dataset': dataset,
                    'Model': 'EDTalk',
                    'ALS_LSE_C': als_lse_c if not np.isnan(als_lse_c) else 0,
                    'Stroke_LSE_C': stroke_lse_c if not np.isnan(stroke_lse_c) else 0
                })
        
        # EDTalk Avatar
        edtalk_avatar_data = final_df[(final_df['Model'] == 'EDTalk') & (final_df['Data_Type'] == 'Avatar')]
        for dataset in ['RAW', 'VCTK']:
            dataset_data = edtalk_avatar_data[edtalk_avatar_data['Dataset'] == dataset]
            if len(dataset_data) > 0:
                als_lse_c = dataset_data[dataset_data['Disease'] == 'ALS']['LSE_C_Mean'].mean()
                stroke_lse_c = dataset_data[dataset_data['Disease'] == 'Stroke']['LSE_C_Mean'].mean()
                
                research_table_data.append({
                    'Dataset': dataset,
                    'Model': 'Avatar-EDTalk',
                    'ALS_LSE_C': als_lse_c if not np.isnan(als_lse_c) else 0,
                    'Stroke_LSE_C': stroke_lse_c if not np.isnan(stroke_lse_c) else 0
                })
        
        if research_table_data:
            research_table_df = pd.DataFrame(research_table_data)
            print("\nFINAL RESEARCH TABLE (LSE-C values):")
            print(research_table_df.round(4).to_string(index=False))
            
            # Save final research table
            research_table_path = "/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/final_lse_research_table.csv"
            research_table_df.to_csv(research_table_path, index=False)
            print(f"\nFinal research table saved to: {research_table_path}")
    
    else:
        print("No LSE evaluation results found!")

# Run the LSE disease-based evaluation
main_lse_disease_evaluation()
# Out:
# ================================================================================
# LSE-C DISEASE-BASED EVALUATION (ALS vs STROKE)
# ================================================================================
# Loaded MuseTalk LSE results: 120 records
# Loaded EDTalk LSE results: 240 records
#
# Processing MuseTalk LSE results...
# Generated 12 entries
#
# Processing EDTalk LSE results...
# Generated 24 entries
#
# ================================================================================
# FINAL LSE RESEARCH TABLE - DISEASE-BASED METRICS
# ================================================================================
#    Model Dataset Data_Type TTS_Method Disease  Count  LSE_D_Mean  LSE_D_Std  LSE_C_Mean  LSE_C_Std
#   EDTalk     RAW    Avatar  CosyVoice     ALS      9      9.0959        0.0      4.4569        0.0
#   EDTalk     RAW    Avatar     XTTSv2     ALS      9      9.0959        0.0      4.4569        0.0
#   EDTalk     RAW    Avatar    YourTTS     ALS      9      9.0959        0.0      4.4569        0.0
#   EDTalk     RAW    Avatar  CosyVoice  Stroke     11      9.0959        0.0      4.4569        0.0
#   EDTalk     RAW    Avatar     XTTSv2  Stroke     11      9.0959        0.0      4.4569        0.0
#   EDTalk     RAW    Avatar    YourTTS  Stroke     11      9.0959        0.0      4.4569        0.0
#   EDTalk     RAW       V15  CosyVoice     ALS      9      9.9286        0.0      2.9676        0.0
#   EDTalk     RAW       V15     XTTSv2     ALS      9      9.9286        0.0      2.9676        0.0
#   EDTalk     RAW       V15    YourTTS     ALS      9      9.9286        0.0      2.9676        0.0
#   EDTalk     RAW       V15  CosyVoice  Stroke     11      9.9286        0.0      2.9676        0.0
#   EDTalk     RAW       V15     XTTSv2  Stroke     11      9.9286        0.0      2.9676        0.0
#   EDTalk     RAW       V15    YourTTS  Stroke     11      9.9286        0.0      2.9676        0.0
#   EDTalk    VCTK    Avatar  CosyVoice     ALS      9      8.7952        0.0      4.2118        0.0
#   EDTalk    VCTK    Avatar     XTTSv2     ALS      9      8.7952        0.0      4.2118        0.0
#   EDTalk    VCTK    Avatar    YourTTS     ALS      9      8.7952        0.0      4.2118        0.0
#   EDTalk    VCTK    Avatar  CosyVoice  Stroke     11      8.7952        0.0      4.2118        0.0
#   EDTalk    VCTK    Avatar     XTTSv2  Stroke     11      8.7952        0.0      4.2118        0.0
#   EDTalk    VCTK    Avatar    YourTTS  Stroke     11      8.7952        0.0      4.2118        0.0
#   EDTalk    VCTK       V15  CosyVoice     ALS      9      9.2247        0.0      3.2529        0.0
#   EDTalk    VCTK       V15     XTTSv2     ALS      9      9.2247        0.0      3.2529        0.0
#   EDTalk    VCTK       V15    YourTTS     ALS      9      9.2247        0.0      3.2529        0.0
#   EDTalk    VCTK       V15  CosyVoice  Stroke     11      9.2247        0.0      3.2529        0.0
#   EDTalk    VCTK       V15     XTTSv2  Stroke     11      9.2247        0.0      3.2529        0.0
#   EDTalk    VCTK       V15    YourTTS  Stroke     11      9.2247        0.0      3.2529        0.0
# MuseTalk     RAW       V15  CosyVoice     ALS      9     11.3385        0.0      2.7150        0.0
# MuseTalk     RAW       V15     XTTSv2     ALS      9     11.3385        0.0      2.7150        0.0
# MuseTalk     RAW       V15    YourTTS     ALS      9     11.3385        0.0      2.7150        0.0
# MuseTalk     RAW       V15  CosyVoice  Stroke     11     11.3385        0.0      2.7150        0.0
# MuseTalk     RAW       V15     XTTSv2  Stroke     11     11.3385        0.0      2.7150        0.0
# MuseTalk     RAW       V15    YourTTS  Stroke     11     11.3385        0.0      2.7150        0.0
# MuseTalk    VCTK       V15  CosyVoice     ALS      9     10.5118        0.0      2.2330        0.0
# MuseTalk    VCTK       V15     XTTSv2     ALS      9     10.5118        0.0      2.2330        0.0
# MuseTalk    VCTK       V15    YourTTS     ALS      9     10.5118        0.0      2.2330        0.0
# MuseTalk    VCTK       V15  CosyVoice  Stroke     11     10.5118        0.0      2.2330        0.0
# MuseTalk    VCTK       V15     XTTSv2  Stroke     11     10.5118        0.0      2.2330        0.0
# MuseTalk    VCTK       V15    YourTTS  Stroke     11     10.5118        0.0      2.2330        0.0
#
# LSE results saved to: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/lse_disease_based_evaluation_summary.csv
#
# ================================================================================
# LSE RESEARCH PAPER SUMMARY
# ================================================================================
#
# MuseTalk:
#   RAW Dataset:
#     V15:
#       ALS (Total: 27 samples):
#         Avg LSE-C across TTS: 2.7150
#         Avg LSE-D across TTS: 11.3385
#       Stroke (Total: 33 samples):
#         Avg LSE-C across TTS: 2.7150
#         Avg LSE-D across TTS: 11.3385
#   VCTK Dataset:
#     V15:
#       ALS (Total: 27 samples):
#         Avg LSE-C across TTS: 2.2330
#         Avg LSE-D across TTS: 10.5118
#       Stroke (Total: 33 samples):
#         Avg LSE-C across TTS: 2.2330
#         Avg LSE-D across TTS: 10.5118
#
# EDTalk:
#   RAW Dataset:
#     V15:
#       ALS (Total: 27 samples):
#         Avg LSE-C across TTS: 2.9676
#         Avg LSE-D across TTS: 9.9286
#       Stroke (Total: 33 samples):
#         Avg LSE-C across TTS: 2.9676
#         Avg LSE-D across TTS: 9.9286
#     Avatar:
#       ALS (Total: 27 samples):
#         Avg LSE-C across TTS: 4.4569
#         Avg LSE-D across TTS: 9.0959
#       Stroke (Total: 33 samples):
#         Avg LSE-C across TTS: 4.4569
#         Avg LSE-D across TTS: 9.0959
#   VCTK Dataset:
#     V15:
#       ALS (Total: 27 samples):
#         Avg LSE-C across TTS: 3.2529
#         Avg LSE-D across TTS: 9.2247
#       Stroke (Total: 33 samples):
#         Avg LSE-C across TTS: 3.2529
#         Avg LSE-D across TTS: 9.2247
#     Avatar:
#       ALS (Total: 27 samples):
#         Avg LSE-C across TTS: 4.2118
#         Avg LSE-D across TTS: 8.7952
#       Stroke (Total: 33 samples):
#         Avg LSE-C across TTS: 4.2118
#         Avg LSE-D across TTS: 8.7952
#
# ================================================================================
# SIMPLIFIED LSE TABLE FOR RESEARCH PAPER
# ================================================================================
#
# SIMPLIFIED LSE TABLE (Averaged across TTS methods):
# Dataset         Model  ALS_LSE_C  ALS_LSE_D  ALS_Count  Stroke_LSE_C  Stroke_LSE_D  Stroke_Count
#     RAW      MuseTalk     2.7150    11.3385         27        2.7150       11.3385            33
#    VCTK      MuseTalk     2.2330    10.5118         27        2.2330       10.5118            33
#     RAW    EDTalk_V15     2.9676     9.9286         27        2.9676        9.9286            33
#     RAW EDTalk_Avatar     4.4569     9.0959         27        4.4569        9.0959            33
#    VCTK    EDTalk_V15     3.2529     9.2247         27        3.2529        9.2247            33
#    VCTK EDTalk_Avatar     4.2118     8.7952         27        4.2118        8.7952            33
#
# Simplified LSE table saved to: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/simplified_lse_disease_table.csv
#
# ================================================================================
# EDTALK: AVATAR vs V15 COMPARISON (LSE-C)
# ================================================================================
#
# RAW - ALS:
#   V15:    LSE-C = 2.9676
#   Avatar: LSE-C = 4.4569
#   Improvement: +1.4893
#
# RAW - Stroke:
#   V15:    LSE-C = 2.9676
#   Avatar: LSE-C = 4.4569
#   Improvement: +1.4893
#
# VCTK - ALS:
#   V15:    LSE-C = 3.2529
#   Avatar: LSE-C = 4.2118
#   Improvement: +0.9589
#
# VCTK - Stroke:
#   V15:    LSE-C = 3.2529
#   Avatar: LSE-C = 4.2118
#   Improvement: +0.9589
#
# Avatar vs V15 Comparison Summary:
# Dataset Disease  V15_LSE_C  Avatar_LSE_C  Improvement
#     RAW     ALS     2.9676        4.4569       1.4893
#     RAW  Stroke     2.9676        4.4569       1.4893
#    VCTK     ALS     3.2529        4.2118       0.9589
#    VCTK  Stroke     3.2529        4.2118       0.9589
#
# ================================================================================
# FINAL TABLE FORMAT FOR RESEARCH PAPER (LSE-C only)
# ================================================================================
#
# FINAL RESEARCH TABLE (LSE-C values):
# Dataset         Model  ALS_LSE_C  Stroke_LSE_C
#     RAW      MuseTalk     2.7150        2.7150
#    VCTK      MuseTalk     2.2330        2.2330
#     RAW        EDTalk     2.9676        2.9676
#    VCTK        EDTalk     3.2529        3.2529
#     RAW Avatar-EDTalk     4.4569        4.4569
#    VCTK Avatar-EDTalk     4.2118        4.2118
#
# Final research table saved to: /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-video/final_lse_research_table.csv
